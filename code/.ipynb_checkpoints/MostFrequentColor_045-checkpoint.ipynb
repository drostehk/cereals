# %%
import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = Image.open('../img/kelvin_cropped/img_045_gmcheerioshoneynut_cropped.png')

image = cv2.imread('../img/kelvin_cropped/img_045_gmcheerioshoneynut_cropped.png')
plt.figure(figsize=(10,5))
plt.axis('off');
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB));

# %%
img.size
# Out:
# (319, 480)

# %%
pixels = img.getcolors(img.size[0] * img.size[1])

# %%
# number, RGBA order
print pixels[0]
# Out:
# (1620, (255, 255, 255, 0))

# %%
# Most frequent colour in image (background excluded)
def most_frequent_colour(image):
    w, h = image.size
    pixels = image.getcolors(w * h)
    
    most_frequent_pixel = pixels[0]
    
    for count, colour in pixels:
        if (count > most_frequent_pixel[0] & colour[3] != 0):
            most_frequent_pixel = (count, colour)
            
    return most_frequent_pixel

# %%
most_frequent_colour(img)
# Out:
# (1890, (141, 28, 20, 255))

# %%
rgb = most_frequent_colour(img)[1][:-1]
print rgb
# Out:
# (141, 28, 20)

# %%
print 'Most Frequent Colour: '
print '#'+''.join(map(chr, rgb)).encode('hex')
print 'with count : ' + str(most_frequent_colour(img)[0])
# Out:
# Most Frequent Colour:
# #8d1c14
# with count : 1890
