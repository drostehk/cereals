# %%
# Ref : http://blog.zeevgilovitz.com/detecting-dominant-colours-in-python/

from PIL import Image
import random
import numpy as np
import pandas as pd
import itertools
import webcolors

# %%
df = pd.read_csv('../data/data_updated.csv')
df = df.drop('Unnamed: 0', 1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#            ...           has_cha  down_gaze  b_mean  g_mean  r_mean   b_sd  \
# 0          ...                 1          0   35.58   71.37  208.29  54.28
# 1          ...                 1          0   53.31  107.21  195.62  46.53
# 2          ...                 1          0   65.40  123.12  191.40  52.63
# 3          ...                 1          0   95.78   78.63  115.69  47.58
# 4          ...                 1          0  108.41  153.04  186.66  48.37
#
#     g_sd   r_sd  most_fre_color  most_fre_color_count
# 0  86.32  62.01         #e70000                   256
# 1  48.07  54.99         #d8501e                   256
# 2  60.91  40.15         #bd582a                   256
# 3  71.51  58.18         #581680                  1272
# 4  51.09  53.44         #ffffff                   681
#
# [5 rows x 26 columns]

# %%
def gen_file_name(row):
    file_name = row.cover_image.split('/')[len(row.cover_image.split('/'))-1]
    file_name = 'img_' + str(row['index']).zfill (3) + '_' + (file_name).lower()
    return(file_name)

# %%
df['file_name'] = df.apply(gen_file_name, axis=1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#                          ...                          down_gaze  b_mean  \
# 0                        ...                                  0   35.58
# 1                        ...                                  0   53.31
# 2                        ...                                  0   65.40
# 3                        ...                                  0   95.78
# 4                        ...                                  0  108.41
#
#    g_mean  r_mean   b_sd   g_sd   r_sd  most_fre_color  most_fre_color_count  \
# 0   71.37  208.29  54.28  86.32  62.01         #e70000                   256
# 1  107.21  195.62  46.53  48.07  54.99         #d8501e                   256
# 2  123.12  191.40  52.63  60.91  40.15         #bd582a                   256
# 3   78.63  115.69  47.58  71.51  58.18         #581680                  1272
# 4  153.04  186.66  48.37  51.09  53.44         #ffffff                   681
#
#                                            file_name
# 0                    img_001_anniesfruitybunnies.jpg
# 1                     img_002_annieshoneybunnies.jpg
# 2              img_003_anniescinnamonrollbunnyos.jpg
# 3                   img_004_anniesorganicbunnyos.jpg
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...
#
# [5 rows x 27 columns]

# %%
# K-mean Clustering

# Class : Cluster
class Cluster(object):

    def __init__(self):
        self.pixels = []
        self.lastpixels = []
        self.centroid = None

    def addPoint(self, pixel):
        self.pixels.append(pixel)
        
    def pixelCount(self):
        return len(self.lastpixels)

    def setNewCentroid(self):

        R = [colour[0] for colour in self.pixels]
        G = [colour[1] for colour in self.pixels]
        B = [colour[2] for colour in self.pixels]

        R = sum(R) / (len(R) + 1)
        G = sum(G) / (len(G) + 1)
        B = sum(B) / (len(B) + 1)
        
        self.centroid = (R, G, B)
        self.lastpixels = self.pixels
        self.pixels = []

        return self.centroid

# %%
# Class : Kmeans
class Kmeans(object):

    def __init__(self, k=3, max_iterations=5, min_distance=2.0, size=300):
        self.k = k
        self.max_iterations = max_iterations
        self.min_distance = min_distance
        self.size = (size, size + 1)

    def run(self, image):
        self.image = image
        self.image.thumbnail(self.size)
        self.pixels = np.array(image.getdata(), dtype=np.uint8)

        self.clusters = [None for i in range(self.k)]
        self.oldClusters = None

        randomPixels = random.sample(self.pixels, self.k)

        for idx in range(self.k):
            self.clusters[idx] = Cluster()
            self.clusters[idx].centroid = randomPixels[idx]

        iterations = 0

        while self.shouldExit(iterations) is False:

            self.oldClusters = [cluster.centroid for cluster in self.clusters]

            # print iterations

            for pixel in self.pixels:
                self.assignClusters(pixel)

            for cluster in self.clusters:
                cluster.setNewCentroid()

            iterations += 1
        
        pixelCounts = [cluster.pixelCount() for cluster in self.clusters]
        
        clusters_centroid = [cluster.centroid for cluster in self.clusters]
        
        return pixelCounts

    def assignClusters(self, pixel):
        shortest = float('Inf')
        for cluster in self.clusters:
            distance = self.calcDistance(cluster.centroid, pixel)
            if distance < shortest:
                shortest = distance
                nearest = cluster

        nearest.addPoint(pixel)

    def calcDistance(self, a, b):

        result = np.sqrt(sum((a - b) ** 2))
        return result

    def shouldExit(self, iterations):

        if self.oldClusters is None:
            return False

        for idx in range(self.k):
            dist = self.calcDistance(
                np.array(self.clusters[idx].centroid),
                np.array(self.oldClusters[idx])
            )
            if dist < self.min_distance:
                return True

        if iterations <= self.max_iterations:
            return False

        return True

    # The remaining methods are used for debugging
    
    def showImage(self):
        self.image.show()

    def showCentroidColours(self):

        for cluster in self.clusters:
            image = Image.new("RGB", (200, 200), cluster.centroid)
            image.show()

    def showClustering(self):

        localPixels = [None] * len(self.image.getdata())

        for idx, pixel in enumerate(self.pixels):
                shortest = float('Inf')
                for cluster in self.clusters:
                    distance = self.calcDistance(
                        cluster.centroid,
                        pixel
                    )
                    if distance < shortest:
                        shortest = distance
                        nearest = cluster

                localPixels[idx] = nearest.centroid

        w, h = self.image.size
        localPixels = np.asarray(localPixels)\
            .astype('uint8')\
            .reshape((h, w, 3))

        colourMap = Image.fromarray(localPixels)
        colourMap.show()
        
    def printCentroidColoursHexCode(self):
        hexcodes = []
        for cluster in self.clusters:
            hexcode = '#'+''.join(map(chr, cluster.centroid)).encode('hex')
            hexcodes.append(hexcode)
            # print cluster.centroid, hexcode
          
        print hexcodes
        
        return hexcodes
    
    def printCentroidColoursRGB(self):
        RGBs = []
        for cluster in self.clusters:
            RGBs.append(cluster.centroid)
        
        print RGB
        
        return RGB

# %%
img_name = df['file_name']

# %%
hexcodes_dominant_color = []
pixels_num_color = []

for i in range(260):
    img = Image.open('../img/' + img_name[i])
    
    k = Kmeans()
    pixels_num = k.run(img)
    
    hexcode = k.printCentroidColoursHexCode()
    print pixels_num
    
    hexcodes_dominant_color.append(hexcode)
    pixels_num_color.append(pixels_num)
# Out:
# ['#fdfcfc', '#d31510', '#c7a43e']
# [40685, 32671, 16644]
# ['#df5a22', '#644f30', '#c4b26e']
# [39109, 10467, 13032]
# ['#c8b347', '#f2e9d8', '#b15329']
# [16192, 11510, 35207]
# ['#4e186f', '#c3af5a', '#756437']
# [34797, 16500, 12816]
# ['#5c4147', '#c89e5d', '#e0ceb3']
# [10803, 34860, 15139]
# ['#623849', '#cda66d', '#e6d6bd']
# [10832, 29772, 19596]
# ['#cdb28d', '#be7c3b', '#412d42']
# [32909, 18499, 6083]
# ['#d4bd9f', '#b8936a', '#603636']
# [20685, 25494, 11613]
# ['#bb8956', '#502f34', '#d2b893']
# [18918, 10631, 27641]
# ['#bf986d', '#523543', '#dccbb4']
# [35640, 7256, 14294]
# ['#b18c66', '#d4bea1', '#403340']
# [22261, 23869, 15876]
# ['#d9c8b0', '#ba976e', '#443c4c']
# [13969, 32544, 10376]
# ['#b7875b', '#d0b695', '#5a3530']
# [19082, 27832, 10878]
# ['#b9946a', '#674334', '#d4c0a6']
# [29000, 9081, 19410]
# ['#b68f6a', '#d4bc9f', '#4c4050']
# [25742, 23176, 8874]
# ['#85765c', '#abb3a6', '#3a3d55']
# [42244, 13667, 11814]
# ['#cfaf94', '#a76443', '#281315']
# [52950, 21778, 14368]
# ['#b79571', '#5e3a38', '#d5bfa5']
# [25726, 11433, 20332]
# ['#6f3e30', '#fdfdfc', '#c3a17b']
# [16088, 35642, 38270]
# ['#c3a37c', '#fcfbf9', '#5f423b']
# [45020, 37848, 7132]
# ['#fdfcfb', '#c19f77', '#57444d']
# [36286, 44370, 9344]
# ['#8a4b38', '#f0e9dc', '#c5a365']
# [19138, 14270, 33414]
# ['#9a6243', '#fdfbf7', '#cfad81']
# [14011, 34881, 41108]
# ['#ccad80', '#8a6451', '#fcfbf9']
# [40358, 15573, 34069]
# ['#c7a37a', '#fdfcfa', '#5c3534']
# [45783, 32531, 11686]
# ['#fbfaf9', '#827650', '#d6aa75']
# [37763, 10211, 19751]
# ['#f8f8f7', '#b8552e', '#bcbfb7']
# [54137, 16886, 18977]
# ['#fbfbf9', '#675638', '#d1b567']
# [49449, 18514, 22037]
# ['#ab9565', '#f7f4ed', '#66542d']
# [21609, 33669, 10641]
# ['#8c6f3d', '#bebdb0', '#e5e8e9']
# [15845, 14562, 25579]
# ['#f0f0ec', '#4c331a', '#a1874a']
# [59514, 10602, 19884]
# ['#c9c1ab', '#f6f6f5', '#82735d']
# [15792, 56167, 18041]
# ['#806938', '#eaeae4', '#b6ac83']
# [15058, 32494, 15658]
# ['#c7c9c2', '#f6f8f8', '#826d47']
# [21945, 49685, 18370]
# ['#f9f8f4', '#c6a474', '#78683a']
# [34987, 17548, 10675]
# ['#a99d7b', '#dadad8', '#7e562f']
# [9780, 34046, 23899]
# ['#e1e7e7', '#938945', '#bbbca9']
# [28779, 16298, 14822]
# ['#f9f8f4', '#b69c6b', '#6a4f37']
# [33856, 20364, 11699]
# ['#f4f3f0', '#585128', '#c06b59']
# [34867, 8225, 22526]
# ['#ecf0f3', '#6c612a', '#d7a861']
# [62407, 4770, 22823]
# ['#faf9f8', '#c1b194', '#6d6127']
# [55737, 12468, 21795]
# ['#8499bb', '#12467b', '#eef6fa']
# [12540, 25836, 51624]
# ['#91904d', '#1d9562', '#dbd8ba']
# [26874, 23470, 10458]
# ['#2c6fab', '#f4e7a6', '#c49b4a']
# [10520, 38691, 18213]
# ['#d8773e', '#eee374', '#801f1b']
# [16695, 22917, 20588]
# ['#ecf0ee', '#917d56', '#244fa7']
# [39444, 18568, 31988]
# ['#b19241', '#d9161c', '#e9ccb9']
# [12232, 32079, 17695]
# ['#f5f5f4', '#b5aaad', '#71554f']
# [50207, 19053, 20740]
# ['#47366b', '#e5d6b3', '#1092cd']
# [30310, 19951, 17765]
# ['#e5bc2b', '#fcfcfb', '#734854']
# [31276, 42175, 16549]
# ['#bcadb0', '#f6f6f5', '#7b636d']
# [18063, 51869, 20068]
# ['#544d7d', '#dca556', '#f4f2ed']
# [18303, 22691, 27032]
# ['#1a539a', '#965f2b', '#d8c896']
# [4842, 30712, 33676]
# ['#bccec9', '#492e29', '#9e6d4b']
# [14304, 28912, 24509]
# ['#803924', '#1f80b2', '#d0c8b5']
# [41226, 6295, 14184]
# ['#f5f5f4', '#95979f', '#a7442e']
# [51449, 18849, 19702]
# ['#629b62', '#b9462b', '#ebedd9']
# [18062, 11819, 28814]
# ['#f7f7f5', '#a08a63', '#a0230f']
# [38428, 24001, 27571]
# ['#f9f7f6', '#a6492e', '#9e979e']
# [56596, 19878, 13526]
# ['#e8ecec', '#328dc4', '#b44937']
# [27575, 17779, 13341]
# ['#f6f6f5', '#b6664d', '#c5bb94']
# [54524, 16032, 19444]
# ['#d19555', '#dfd1d5', '#725043']
# [18141, 33847, 17242]
# ['#226771', '#d9bd8d', '#c92249']
# [9008, 19590, 34612]
# ['#a15b2a', '#3e2f27', '#c5b68a']
# [23752, 24690, 18380]
# ['#99616e', '#3f1218', '#f7f7ee']
# [17939, 27633, 23357]
# ['#f8f8f8', '#a3abb3', '#3e4c70']
# [49199, 15753, 25048]
# ['#c1b146', '#eff1f1', '#65426a']
# [15890, 31392, 23152]
# ['#e0b55b', '#955323', '#571d0f']
# [23156, 16014, 26147]
# ['#f6f6f6', '#a9b4b3', '#644b72']
# [17530, 6434, 6661]
# ['#6e435d', '#d29a79', '#f8f6f3']
# [17556, 15122, 32639]
# ['#eff0ee', '#585247', '#b8af8c']
# [34280, 18664, 14781]
# ['#e7aa68', '#4391cb', '#5f4334']
# [31640, 13736, 18737]
# ['#b76939', '#f3e5c5', '#2e81a6']
# [29492, 29879, 8053]
# ['#c4a879', '#f8f3eb', '#465575']
# [14511, 51145, 24344]
# ['#1e99cf', '#f6e7c4', '#c1883f']
# [5781, 31596, 30649]
# ['#f1ecce', '#e49d49', '#5a585d']
# [27996, 21111, 17414]
# ['#6b567c', '#c78867', '#f8e8cd']
# [21698, 17441, 28586]
# ['#e7ebed', '#d36224', '#4b6ca1']
# [62842, 16639, 10519]
# ['#e189b0', '#4b2055', '#ad3171']
# [27507, 27305, 14418]
# ['#e7b72f', '#edebe8', '#435f95']
# [31757, 22092, 13876]
# ['#4773a0', '#d4a329', '#e8e5cc']
# [19039, 29545, 20044]
# ['#6d624a', '#ede3d6', '#8c2673']
# [16164, 11162, 34078]
# ['#ca6930', '#f9f8f5', '#204bb5']
# [29458, 44695, 15847]
# ['#2c4486', '#e4791e', '#f9f9f7']
# [11808, 31210, 46982]
# ['#d6a84f', '#fcfbfa', '#a92420']
# [26406, 40380, 23214]
# ['#fbf9f7', '#c8b36e', '#59332c']
# [39624, 26716, 23660]
# ['#b9a067', '#a63337', '#e1dcd0']
# [15915, 22654, 30962]
# ['#efeced', '#8a1615', '#8b7586']
# [24224, 6373, 9403]
# ['#e3dac2', '#c9a46c', '#814557']
# [22861, 22255, 23211]
# ['#623e27', '#e08122', '#fbfbf8']
# [15510, 28582, 45908]
# ['#b54540', '#441e5b', '#efe7e4']
# [20273, 32357, 15396]
# ['#0e85be', '#a9443b', '#edf1ed']
# [26159, 22827, 16933]
# ['#f3ebe2', '#db8f42', '#72303b']
# [26624, 16125, 18053]
# ['#8c4d46', '#b7b57c', '#f7f9f9']
# [27119, 15018, 47863]
# ['#aed3e1', '#8a5b3d', '#ed5a29']
# [14718, 9554, 37132]
# ['#a63f33', '#d8b9a7', '#100b0e']
# [11601, 11779, 42840]
# ['#c1a75c', '#ebeae7', '#3e2210']
# [20733, 51294, 17973]
# ['#cda672', '#655231', '#faf8f4']
# [14630, 15438, 29831]
# ['#f6f2ef', '#cc935f', '#763328']
# [28839, 16271, 13585]
# ['#1f8049', '#a0865c', '#f4f2ea']
# [21523, 19571, 16999]
# ['#fbf9f6', '#ac927c', '#6f4031']
# [43257, 16650, 30093]
# ['#f7f8f7', '#cfaa67', '#675633']
# [31973, 11731, 21914]
# ['#e4dbc3', '#f1c65b', '#9f393c']
# [11962, 20664, 8939]
# ['#ae7740', '#3c5e9a', '#f4f0ea']
# [13001, 29559, 16436]
# ['#065b98', '#efece8', '#b28348']
# [26728, 18653, 12712]
# ['#e8b75e', '#6c4325', '#0b7ab5']
# [43062, 12132, 10424]
# ['#edc36b', '#c67b31', '#115c80']
# [32822, 16853, 15943]
# ['#c9cfc3', '#237489', '#d99d2d']
# [10264, 17548, 35398]
# ['#eed2b3', '#c22622', '#000000']
# [86019, 3981, 0]
# ['#d1764b', '#522a2b', '#f1ece3']
# [21700, 15250, 26862]
# ['#fbf9f5', '#502a28', '#7a8e6d']
# [46465, 15143, 28392]
# ['#faf9f7', '#763a1a', '#c8a06d']
# [45233, 29489, 15278]
# ['#d3cbb4', '#5d4d73', '#d14231']
# [19120, 22791, 15881]
# ['#485245', '#d13d2b', '#cdcab9']
# [20774, 23223, 16203]
# ['#ca6832', '#dcdcda', '#0f5d8a']
# [17543, 16410, 25946]
# ['#155894', '#c9683b', '#f4f5f5']
# [23040, 19169, 47791]
# ['#fbfbfa', '#b22918', '#bdac4c']
# [47707, 25577, 16716]
# ['#ebecc8', '#e0ac38', '#6a7248']
# [26935, 17852, 17821]
# ['#eae8ce', '#bfcd3e', '#745f2e']
# [15298, 32061, 11336]
# ['#235c8a', '#c86140', '#eaeae7']
# [12861, 24624, 26026]
# ['#2c496c', '#d29847', '#e5e7e8']
# [19969, 23985, 20761]
# ['#969dab', '#dcddcb', '#315d81']
# [25206, 21659, 15743]
# ['#3a4a3a', '#c29573', '#f2f2f1']
# [18778, 23201, 21833]
# ['#b7a182', '#4d4c4b', '#f5f7f8']
# [16966, 26143, 19499]
# ['#5a5963', '#f5f5f6', '#d38d9c']
# [16036, 19991, 24775]
# ['#faf9f6', '#b49567', '#20669d']
# [61401, 9935, 18664]
# ['#eceff0', '#444972', '#9c9b7c']
# [19347, 31385, 22110]
# ['#432f2f', '#d8dadd', '#877c69']
# [26405, 17418, 16979]
# ['#b68829', '#435f76', '#d5d7d0']
# [20346, 19165, 27010]
# ['#dc8c3e', '#156d7f', '#e1d9c5']
# [25083, 12705, 26927]
# ['#f7f4f5', '#bd5736', '#7c1e0d']
# [59902, 20861, 9237]
# ['#efe4da', '#c5143d', '#d29553']
# [28077, 26227, 8605]
# ['#f8f8f8', '#80808f', '#502836']
# [49063, 24912, 16025]
# ['#f5f3f1', '#bf884f', '#5e1b40']
# [18554, 17861, 24387]
# ['#6a5f64', '#dbd5ca', '#67b8d5']
# [17074, 28502, 17333]
# ['#f8f9fa', '#d1a074', '#5c4984']
# [48969, 13566, 27465]
# ['#a07050', '#1c608a', '#e3e3e3']
# [16818, 29264, 18633]
# ['#5086ab', '#c0b095', '#594846']
# [5604, 28836, 20643]
# ['#babec4', '#826b50', '#fafafb']
# [16629, 18076, 55295]
# ['#955d30', '#c9ae8e', '#f4eee8']
# [20702, 10284, 32224]
# ['#d6d3c9', '#16acd5', '#764422']
# [19999, 22147, 21064]
# ['#5f6a97', '#dbd9e0', '#c03b42']
# [20079, 28613, 14518]
# ['#b89d88', '#f8f4f1', '#a54132']
# [18242, 26226, 19344]
# ['#c4a869', '#c04332', '#f4e5d9']
# [22509, 12887, 27513]
# ['#cf3832', '#f1edf1', '#a691a6']
# [12086, 29995, 20828]
# ['#ecf0f4', '#6eacce', '#c85441']
# [30848, 17243, 14818]
# ['#f6f0f1', '#be9391', '#ad1c12']
# [61623, 13726, 14651]
# ['#f5f5f5', '#c7c8c6', '#c65d54']
# [44310, 11710, 11705]
# ['#b13739', '#f5e3c3', '#b3926b']
# [17635, 34400, 11777]
# ['#dfdedd', '#95433a', '#a2a39b']
# [25570, 19262, 22893]
# ['#6690a1', '#7f552a', '#d6e4df']
# [16811, 26374, 22433]
# ['#c07a23', '#fbf9f6', '#a9a08c']
# [12038, 23583, 4379]
# ['#f5f5f3', '#683012', '#d36140']
# [24804, 3427, 11769]
# ['#fbfaf6', '#cd9a5a', '#534865']
# [40291, 24774, 24935]
# ['#633c1f', '#c3ac8d', '#faf8f5']
# [13031, 13489, 25252]
# ['#f0efed', '#74351d', '#caa479']
# [23021, 8867, 10973]
# ['#725f3d', '#f6f3ed', '#db9157']
# [10732, 44831, 20289]
# ['#f4f3f2', '#7d543b', '#c6aa90']
# [52036, 21849, 16115]
# ['#f6f5f5', '#dac9a6', '#988141']
# [44111, 16812, 19143]
# ['#a07338', '#fbfaf8', '#d0b495']
# [14934, 42384, 8300]
# ['#a84323', '#e6e6dd', '#c7a97d']
# [16401, 36546, 13574]
# ['#d4bb81', '#fafaf9', '#b67a2d']
# [11416, 32258, 15623]
# ['#fbfaf7', '#5f1c26', '#cba47e']
# [38336, 14115, 12264]
# ['#fbf8ee', '#77141c', '#b6805d']
# [23204, 28777, 12132]
# ['#faf8f7', '#c39067', '#69432f']
# [69594, 14053, 6353]
# ['#f5f6f6', '#a5887a', '#4e402e']
# [47952, 10397, 6971]
# ['#ae947a', '#f5f4f3', '#753a12']
# [11898, 40691, 7009]
# ['#baad96', '#8b6430', '#e5e4e5']
# [9906, 20882, 30917]
# ['#e7d1a2', '#b49944', '#fdfdfc']
# [7998, 13625, 68377]
# ['#a78d7c', '#faf9f6', '#7c373a']
# [6956, 38596, 12541]
# ['#613e30', '#bba5a1', '#f1f1f3']
# [17277, 12664, 60059]
# ['#f6f4f3', '#a98272', '#50362f']
# [41726, 8786, 8183]
# ['#e6dcd4', '#7c3e3a', '#000000']
# [63495, 9949, 0]
# ['#c2c1a8', '#692646', '#000000']
# [85152, 4848, 0]
# ['#f3e3d2', '#693721', '#000000']
# [82320, 7680, 0]
# ['#9a694c', '#f8f8f8', '#c2aea1']
# [23916, 55584, 10500]
# ['#a37334', '#ddbf8f', '#fdfcfc']
# [15326, 8014, 52512]
# ['#e3d9d7', '#cc9524', '#49483b']
# [40374, 7002, 17339]
# ['#c1b56d', '#fafaf7', '#42643a']
# [15249, 70047, 4704]
# ['#a98368', '#732417', '#ece9de']
# [10106, 23766, 17452]
# ['#c5c5c7', '#8d845b', '#434c32']
# [21704, 21122, 17374]
# ['#c7ac8f', '#cc653a', '#733c2e']
# [15634, 31767, 19120]
# ['#fbfaf7', '#d2b877', '#71552f']
# [50459, 23454, 16087]
# ['#c39d3e', '#7e4918', '#1e2d0d']
# [17347, 18061, 19374]
# ['#2f3527', '#727e59', '#d9cfa5']
# [20139, 18998, 20461]
# ['#4c7075', '#b5896c', '#f5f4ef']
# [16914, 21366, 18910]
# ['#f2f1ea', '#b7ac59', '#605a38']
# [21036, 20406, 15748]
# ['#bb986b', '#f5f4f0', '#514f40']
# [21634, 21181, 14375]
# ['#f8f7ef', '#1b3c66', '#b68a61']
# [48691, 17335, 23974]
# ['#953c33', '#f7f3ee', '#49291e']
# [31528, 52185, 6287]
# ['#fcfaf4', '#cf9a71', '#9a4f2c']
# [51623, 13137, 25240]
# ['#dcad67', '#4a3439', '#fcf9ef']
# [24847, 16155, 14984]
# ['#582c4f', '#814537', '#9b8386']
# [30850, 26135, 10740]
# ['#f3d39e', '#522a14', '#977240']
# [35781, 14028, 6177]
# ['#693f16', '#faf9f7', '#b47c26']
# [18963, 31378, 17083]
# ['#e7ded4', '#664330', '#000000']
# [85608, 4392, 0]
# ['#f8f9f5', '#1d517f', '#b9915a']
# [42948, 28415, 18637]
# ['#4b6d43', '#fcfbf4', '#e2c26f']
# [11975, 55172, 22853]
# ['#b48c65', '#ded9d3', '#1b69a4']
# [16398, 29487, 18228]
# ['#df9226', '#fdfcfb', '#615920']
# [23255, 41266, 2979]
# ['#f5f8f7', '#da9d26', '#37668b']
# [40461, 32821, 16718]
# ['#a95b41', '#d9d4ce', '#f4f4f5']
# [14954, 10954, 64092]
# ['#cec5c2', '#fcfcfc', '#754150']
# [18100, 41202, 8198]
# ['#9b4927', '#f5f3ee', '#f1b336']
# [17599, 48199, 24202]
# ['#e3e9e5', '#385063', '#e49e27']
# [23838, 17210, 19754]
# ['#a83e34', '#ebad57', '#edeae8']
# [20640, 15480, 21973]
# ['#9d211c', '#d9902e', '#f3f1f3']
# [23026, 16832, 50142]
# ['#efab36', '#f6f1e7', '#626334']
# [29109, 47112, 13779]
# ['#e8c150', '#fbfbfa', '#57734c']
# [11986, 58760, 10854]
# ['#a89a50', '#6f4727', '#dfe2e5']
# [18568, 27668, 22693]
# ['#f1bd41', '#eee7d1', '#744d32']
# [26279, 22888, 11635]
# ['#f6f6f0', '#355384', '#cfa02e']
# [46956, 11294, 31750]
# ['#b0843d', '#e2d8d0', '#51231a']
# [23628, 11116, 23951]
# ['#eac226', '#c7bdac', '#9d3333']
# [11194, 15172, 36844]
# ['#c3a059', '#ece7e3', '#a9461b']
# [20593, 13404, 29213]
# ['#d4d3d3', '#e2ac23', '#125e8d']
# [15957, 19775, 25070]
# ['#50233a', '#524886', '#dcd0bb']
# [20648, 20649, 15893]
# ['#c5924a', '#1a4668', '#eee9d2']
# [22364, 17696, 17130]
# ['#c27131', '#e4c083', '#f8f6f3']
# [23507, 10395, 56098]
# ['#d99665', '#9a2629', '#f2eddf']
# [19559, 20151, 17781]
# ['#f5f3f0', '#d6b182', '#713528']
# [54137, 17573, 18290]
# ['#7c2722', '#db9151', '#f1eadb']
# [21779, 18027, 17384]
# ['#f7f7f8', '#bdb5b0', '#b4760e']
# [49420, 13297, 27283]
# ['#f4e4d5', '#b97159', '#cd2527']
# [14792, 9175, 39544]
# ['#f8f0e5', '#cb6236', '#f3993b']
# [13026, 21498, 29890]
# ['#c98567', '#ca2628', '#f7ebdf']
# [9018, 41307, 13186]
# ['#ac8265', '#eee6d7', '#7d3828']
# [7471, 12801, 39025]
# ['#a6bcc4', '#f1f6f8', '#3a8cb6']
# [17992, 52969, 19039]
# ['#da831e', '#fafaf8', '#3a3d40']
# [34390, 47950, 7660]
# ['#bebdb5', '#5c6f8d', '#7e452e']
# [37812, 12865, 17048]
# ['#8b4d28', '#fdfdfd', '#bec4c4']
# [21224, 40573, 28203]
# ['#994d20', '#fdfdfd', '#bec3c2']
# [20510, 42253, 27237]
# ['#f6fafc', '#aaaa9d', '#c66a32']
# [58395, 12685, 18920]
# ['#cca265', '#f2f6f7', '#c42719']
# [16202, 65424, 8374]
# ['#e58245', '#f6fafb', '#b2bcc3']
# [16471, 61123, 12406]
# ['#f1f7f8', '#bdb19b', '#d75512']
# [62321, 9327, 18352]
# ['#e6ded4', '#ba2730', '#000000']
# [84198, 5802, 0]
# ['#b1afa2', '#c06339', '#f8fcfd']
# [9640, 16676, 63684]
# ['#bf8764', '#f8fbfc', '#514a21']
# [17558, 70213, 2229]
# ['#e7f0f3', '#a89e97', '#c05937']
# [25952, 14682, 17760]
# ['#e6f0f0', '#899997', '#ca6e32']
# [26231, 11653, 20510]
# ['#ede7de', '#ca2914', '#000000']
# [83324, 6676, 0]
# ['#3f3244', '#eae3d3', '#bf6418']
# [16250, 14985, 23848]
# ['#ecc264', '#7d8393', '#63413e']
# [37321, 10900, 19805]
# ['#8c8f85', '#e9e7e1', '#b7312e']
# [24412, 20421, 23193]
# ['#af8d40', '#5e3c29', '#e9e6d7']
# [19079, 32238, 15505]
# ['#c6d0a0', '#8e6952', '#324c68']
# [23398, 12773, 28544]
# ['#f4df8c', '#ac493c', '#16466f']
# [35847, 18544, 13635]
# ['#4f3344', '#b2895c', '#e0dcd1']
# [26595, 25953, 14274]
# ['#e1e4e5', '#8c9d9f', '#755d3b']
# [34164, 10516, 20336]
# ['#28273e', '#fafaf7', '#938474']
# [11153, 22769, 6078]
# ['#7c363f', '#25558b', '#ede0cb']
# [22753, 10320, 25622]
# ['#bdb58e', '#3f4040', '#f9f9fa']
# [23487, 22540, 43973]
# ['#402e48', '#9a6f6d', '#ccc1bb']
# [30925, 15027, 20948]
# ['#1e2f65', '#f7f3ef', '#bc3f24']
# [14775, 33395, 41830]
# ['#1279ae', '#ced4ca', '#cf6147']
# [50366, 16798, 14407]
# ['#f0e3d4', '#29406f', '#df8446']
# [11107, 16401, 40819]
# ['#bf6f34', '#233f72', '#e8d3bb']
# [39994, 13046, 15287]
# ['#9aa4a2', '#b25929', '#ebebe9']
# [8247, 24281, 39110]
# ['#958d8d', '#8b6442', '#573d25']
# [29899, 18150, 22084]

# %%
print len(pixels_num_color)
# Out:
# 260

# %%
print len(hexcodes_dominant_color)
# Out:
# 260

# %%
pixels_num_color[0]
# Out:
# [40685, 32671, 16644]

# %%
hexcodes_dominant_color[0][np.argmax(pixels_num_color[0])]
# Out:
# '#fdfcfc'

# %%
most_domin_colors = []
for i in range(len(pixels_num_color)):
    most_domin_colors.append(hexcodes_dominant_color[i][np.argmax(pixels_num_color[i])])

# %%
# most_domin_colors return the most dominant color in each image
print most_domin_colors
# Out:
# ['#fdfcfc', '#df5a22', '#b15329', '#4e186f', '#c89e5d', '#cda66d', '#cdb28d', '#b8936a', '#d2b893', '#bf986d', '#d4bea1', '#ba976e', '#d0b695', '#b9946a', '#b68f6a', '#85765c', '#cfaf94', '#b79571', '#c3a17b', '#c3a37c', '#c19f77', '#c5a365', '#cfad81', '#ccad80', '#c7a37a', '#fbfaf9', '#f8f8f7', '#fbfbf9', '#f7f4ed', '#e5e8e9', '#f0f0ec', '#f6f6f5', '#eaeae4', '#f6f8f8', '#f9f8f4', '#dadad8', '#e1e7e7', '#f9f8f4', '#f4f3f0', '#ecf0f3', '#faf9f8', '#eef6fa', '#91904d', '#f4e7a6', '#eee374', '#ecf0ee', '#d9161c', '#f5f5f4', '#47366b', '#fcfcfb', '#f6f6f5', '#f4f2ed', '#d8c896', '#492e29', '#803924', '#f5f5f4', '#ebedd9', '#f7f7f5', '#f9f7f6', '#e8ecec', '#f6f6f5', '#dfd1d5', '#c92249', '#3e2f27', '#3f1218', '#f8f8f8', '#eff1f1', '#571d0f', '#f6f6f6', '#f8f6f3', '#eff0ee', '#e7aa68', '#f3e5c5', '#f8f3eb', '#f6e7c4', '#f1ecce', '#f8e8cd', '#e7ebed', '#e189b0', '#e7b72f', '#d4a329', '#8c2673', '#f9f8f5', '#f9f9f7', '#fcfbfa', '#fbf9f7', '#e1dcd0', '#efeced', '#814557', '#fbfbf8', '#441e5b', '#0e85be', '#f3ebe2', '#f7f9f9', '#ed5a29', '#100b0e', '#ebeae7', '#faf8f4', '#f6f2ef', '#1f8049', '#fbf9f6', '#f7f8f7', '#f1c65b', '#3c5e9a', '#065b98', '#e8b75e', '#edc36b', '#d99d2d', '#eed2b3', '#f1ece3', '#fbf9f5', '#faf9f7', '#5d4d73', '#d13d2b', '#0f5d8a', '#f4f5f5', '#fbfbfa', '#ebecc8', '#bfcd3e', '#eaeae7', '#d29847', '#969dab', '#c29573', '#4d4c4b', '#d38d9c', '#faf9f6', '#444972', '#432f2f', '#d5d7d0', '#e1d9c5', '#f7f4f5', '#efe4da', '#f8f8f8', '#5e1b40', '#dbd5ca', '#f8f9fa', '#1c608a', '#c0b095', '#fafafb', '#f4eee8', '#16acd5', '#dbd9e0', '#f8f4f1', '#f4e5d9', '#f1edf1', '#ecf0f4', '#f6f0f1', '#f5f5f5', '#f5e3c3', '#dfdedd', '#7f552a', '#fbf9f6', '#f5f5f3', '#fbfaf6', '#faf8f5', '#f0efed', '#f6f3ed', '#f4f3f2', '#f6f5f5', '#fbfaf8', '#e6e6dd', '#fafaf9', '#fbfaf7', '#77141c', '#faf8f7', '#f5f6f6', '#f5f4f3', '#e5e4e5', '#fdfdfc', '#faf9f6', '#f1f1f3', '#f6f4f3', '#e6dcd4', '#c2c1a8', '#f3e3d2', '#f8f8f8', '#fdfcfc', '#e3d9d7', '#fafaf7', '#732417', '#c5c5c7', '#cc653a', '#fbfaf7', '#1e2d0d', '#d9cfa5', '#b5896c', '#f2f1ea', '#bb986b', '#f8f7ef', '#f7f3ee', '#fcfaf4', '#dcad67', '#582c4f', '#f3d39e', '#faf9f7', '#e7ded4', '#f8f9f5', '#fcfbf4', '#ded9d3', '#fdfcfb', '#f5f8f7', '#f4f4f5', '#fcfcfc', '#f5f3ee', '#e3e9e5', '#edeae8', '#f3f1f3', '#f6f1e7', '#fbfbfa', '#6f4727', '#f1bd41', '#f6f6f0', '#51231a', '#9d3333', '#a9461b', '#125e8d', '#524886', '#c5924a', '#f8f6f3', '#9a2629', '#f5f3f0', '#7c2722', '#f7f7f8', '#cd2527', '#f3993b', '#ca2628', '#7d3828', '#f1f6f8', '#fafaf8', '#bebdb5', '#fdfdfd', '#fdfdfd', '#f6fafc', '#f2f6f7', '#f6fafb', '#f1f7f8', '#e6ded4', '#f8fcfd', '#f8fbfc', '#e7f0f3', '#e6f0f0', '#ede7de', '#bf6418', '#ecc264', '#8c8f85', '#5e3c29', '#324c68', '#f4df8c', '#4f3344', '#e1e4e5', '#fafaf7', '#ede0cb', '#f9f9fa', '#402e48', '#bc3f24', '#1279ae', '#df8446', '#bf6f34', '#ebebe9', '#958d8d']

# %%
print most_domin_colors[48]
# Out:
# #47366b

# %%
def hex_to_rgb(value):
    value = value.lstrip('#')
    lv = len(value)
    return tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))

# %%
hex_to_rgb('#958d8d')
# Out:
# (149, 141, 141)

# %%
def closest_colour(requested_colour):
    pri_color = ['Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Violet', 'Brown', 'Black', 'Grey', 'White']
    pri_color = [x.lower() for x in pri_color]
    min_colours = {}
    #for key, name in webcolors.css3_hex_to_names.items():
    for key, name in [x for x in itertools.ifilter(lambda x: x[1]  in pri_color, webcolors.css3_hex_to_names.items())]:
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

# %%
closest_colour(hex_to_rgb(most_domin_colors[0]))
# Out:
# u'white'

# %%
domin_colors = []
for i in range(260):
    domin_colors.append(closest_colour(hex_to_rgb(most_domin_colors[i])))

# %%
print domin_colors
# Out:
# [u'white', u'brown', u'brown', u'brown', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'violet', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'grey', u'white', u'yellow', u'white', u'red', u'white', u'grey', u'white', u'white', u'white', u'violet', u'brown', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'black', u'black', u'white', u'white', u'brown', u'white', u'white', u'white', u'orange', u'white', u'white', u'white', u'white', u'white', u'white', u'violet', u'orange', u'orange', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'brown', u'grey', u'white', u'white', u'brown', u'black', u'white', u'white', u'white', u'green', u'white', u'white', u'orange', u'grey', u'grey', u'orange', u'orange', u'orange', u'white', u'white', u'white', u'white', u'grey', u'brown', u'grey', u'white', u'white', u'white', u'orange', u'white', u'orange', u'grey', u'grey', u'grey', u'violet', u'white', u'grey', u'black', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'grey', u'grey', u'white', u'white', u'grey', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'grey', u'white', u'white', u'white', u'white', u'white', u'brown', u'violet', u'brown', u'white', u'black', u'violet', u'grey', u'white', u'grey', u'white', u'white', u'white', u'grey', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'orange', u'white', u'brown', u'brown', u'brown', u'grey', u'grey', u'grey', u'white', u'brown', u'white', u'brown', u'white', u'brown', u'orange', u'brown', u'brown', u'white', u'white', u'violet', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'orange', u'grey', u'brown', u'grey', u'white', u'brown', u'white', u'white', u'white', u'white', u'brown', u'brown', u'grey', u'orange', u'brown', u'white', u'grey']

# %%
def genDominColor(row):
    return domin_colors[row['index'] - 1]

# %%
df['most_domin_color'] = df.apply(genDominColor, axis = 1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#          ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 0        ...          35.58   71.37  208.29  54.28  86.32  62.01
# 1        ...          53.31  107.21  195.62  46.53  48.07  54.99
# 2        ...          65.40  123.12  191.40  52.63  60.91  40.15
# 3        ...          95.78   78.63  115.69  47.58  71.51  58.18
# 4        ...         108.41  153.04  186.66  48.37  51.09  53.44
#
#    most_fre_color  most_fre_color_count  \
# 0         #e70000                   256
# 1         #d8501e                   256
# 2         #bd582a                   256
# 3         #581680                  1272
# 4         #ffffff                   681
#
#                                            file_name  most_domin_color
# 0                    img_001_anniesfruitybunnies.jpg             white
# 1                     img_002_annieshoneybunnies.jpg             brown
# 2              img_003_anniescinnamonrollbunnyos.jpg             brown
# 3                   img_004_anniesorganicbunnyos.jpg             brown
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...              grey
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#     target_market  score                                        cover_image  \
# 255         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 256         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 257         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 258        Family     58  http://cerealfacts.org/media/cereal_images/Qua...
# 259        Family     58  http://cerealfacts.org/media/cereal_images/Qua...
#
#     sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 255          16%           9%            339                  9
# 256          16%           9%            339                  9
# 257          16%           9%            339                  9
# 258          19%          19%            281                  6
# 259          22%          19%            281                  7
#
#      fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 255                  5                 190                   210
# 256                  5                 190                   210
# 257                  5                 190                   210
# 258                  6                  90                   110
# 259                  6                  90                   110
#
#            ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 255        ...         164.55  136.89   90.92  62.61  58.52  98.70
# 256        ...          97.41  126.17  178.93  58.60  61.11  85.87
# 257        ...          91.22  121.25  167.26  65.59  61.71  74.12
# 258        ...         158.91  175.17  203.98  90.90  73.27  47.04
# 259        ...          88.67  104.01  126.50  51.30  39.40  38.09
#
#      most_fre_color  most_fre_color_count  \
# 255         #0093d8                   249
# 256         #26397b                  1792
# 257         #1b4482                   256
# 258         #e4e3e1                   148
# 259         #817d7c                   256
#
#                                          file_name  most_domin_color
# 255     img_256_quakeroatmealsquaresbrownsugar.jpg              grey
# 256       img_257_quakeroatmealsquarescinnamon.jpg            orange
# 257    img_258_quakeroatmealsquaresgoldenmaple.jpg             brown
# 258     img_259_quakerlifecrunchtimestrawberry.jpg             white
# 259  img_260_quakerlifecrunchtimeapplecinnamon.jpg              grey
#
# [5 rows x 28 columns]

# %%
df.to_csv('../data/data_updated.csv')
