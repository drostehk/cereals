# %%
import cv2
import math
import random
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.9

# %%
df = pd.read_csv('../data/data.csv')
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  serving_size  \
# 0                  1                  85                   120            29
# 1                  1                  90                   110            29
# 2                  1                  85                   120            29
# 3                  1                 110                   120            29
# 4                  3                  80                   120            30
#
#    index                                                url
# 0      1  http://cerealfacts.org/cereal_nutrition_scores...
# 1      2  http://cerealfacts.org/cereal_nutrition_scores...
# 2      3  http://cerealfacts.org/cereal_nutrition_scores...
# 3      4  http://cerealfacts.org/cereal_nutrition_scores...
# 4      5  http://cerealfacts.org/cereal_nutrition_scores...

# %%
def gen_file_name(row):
    file_name = row.cover_image.split('/')[len(row.cover_image.split('/'))-1]
    file_name = 'img_' + str(row['index']).zfill (3) + '_' + (file_name).lower()[:-4] + '_cropped.png'
    return(file_name)

# %%
df['file_name_cropped'] = df.apply(gen_file_name, axis=1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  serving_size  \
# 0                  1                  85                   120            29
# 1                  1                  90                   110            29
# 2                  1                  85                   120            29
# 3                  1                 110                   120            29
# 4                  3                  80                   120            30
#
#    index                                                url  \
# 0      1  http://cerealfacts.org/cereal_nutrition_scores...
# 1      2  http://cerealfacts.org/cereal_nutrition_scores...
# 2      3  http://cerealfacts.org/cereal_nutrition_scores...
# 3      4  http://cerealfacts.org/cereal_nutrition_scores...
# 4      5  http://cerealfacts.org/cereal_nutrition_scores...
#
#                                    file_name_cropped
# 0            img_001_anniesfruitybunnies_cropped.png
# 1             img_002_annieshoneybunnies_cropped.png
# 2      img_003_anniescinnamonrollbunnyos_cropped.png
# 3           img_004_anniesorganicbunnyos_cropped.png
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...

# %%
# Restructure the alpha_img into 1D array for sampling
def reform(alpha_img):
    new_alpha_img = []
    for i in range(alpha_img.shape[0]):
        for j in range(alpha_img.shape[1]):
            new_alpha_img.append(alpha_img[i][j])
    return new_alpha_img

# %%
# Colour Mean of image EXCLUDING background
def colourMean(alpha_img):
    b = [];g = [];r = []; a = [] # b: Blue, g: Green, r: Red, a: Alpha
    for i in range(alpha_img.shape[0]):
        for j in range(alpha_img.shape[1]):
            if(alpha_img[i][j][3] != 0):
                b.append(alpha_img[i][j][0])
                g.append(alpha_img[i][j][1])
                r.append(alpha_img[i][j][2])
                a.append(alpha_img[i][j][3])
                
    return [round(np.mean(b), 2) , round(np.mean(g), 2), round(np.mean(r), 2), round(np.mean(a), 2)]

# %%
# Sample Colour Mean of image EXCLUDING background
def SampleColourMean(rdm_sample):
    b = [];g = [];r = []; a = [] # b: Blue, g: Green, r: Red, a: Alpha
    for i in range(len(alpha_img)):
        if(rdm_sample[i][3] != 0):
            b.append(rdm_sample[i][0])
            g.append(rdm_sample[i][1])
            r.append(rdm_sample[i][2])
            a.append(rdm_sample[i][3])
                
    return [round(np.mean(b), 2) , round(np.mean(g), 2), round(np.mean(r), 2), round(np.mean(a), 2)]

# %%
# Colour standard deviation of image EXCLUDING background
def colourSD(alpha_img):
    means = colourMean(alpha_img)
    b = []; g = []; r = []; a = []
    for i in range(alpha_img.shape[0]):
        for j in range(alpha_img.shape[1]):
            if(alpha_img[i][j][3] != 0):
                b.append((alpha_img[i][j][0] - means[0]) ** 2)
                g.append((alpha_img[i][j][1] - means[1]) ** 2)
                r.append((alpha_img[i][j][2] - means[2]) ** 2)
                a.append((alpha_img[i][j][3] - means[3]) ** 2)
    
    sd_b = round(math.sqrt(np.mean(b)), 2)
    sd_g = round(math.sqrt(np.mean(g)), 2)
    sd_r = round(math.sqrt(np.mean(r)), 2)
    sd_a = round(math.sqrt(np.mean(a)), 2)
    
    return [sd_b, sd_g, sd_r, sd_a]

# %%
# Sample Colour Standard Deviation of image EXCLUDING background
def SampleColourSD(rdm_sample):
    means = SampleColourMean(rdm_sample)
    b = [];g = [];r = []; a = [] # b: Blue, g: Green, r: Red, a: Alpha
    for i in range(len(rdm_sample)):
        if(rdm_sample[i][3] != 0):
            b.append((rdm_sample[i][0] - means[0]) ** 2)
            g.append((rdm_sample[i][1] - means[1]) ** 2)
            r.append((rdm_sample[i][2] - means[2]) ** 2)
            a.append((rdm_sample[i][3] - means[3]) ** 2)
            
    sd_b = round(math.sqrt(np.mean(b)), 2)
    sd_g = round(math.sqrt(np.mean(g)), 2)
    sd_r = round(math.sqrt(np.mean(r)), 2)
    sd_a = round(math.sqrt(np.mean(a)), 2)
    
    return [sd_b, sd_g, sd_r, sd_a]

# %%
# return a 1 x 6 array represents BGR mean and standard deviation excluded background
def colourMeanSD(alpha_img):
    means = colourMean(alpha_img)
    stds = colourSD(alpha_img)
    return means[:3] + stds[:3]

# return a 1 x 6 array represents BGR Sample mean and standard deviation excluded background
def SampleColourMeanSD(rdm_sample):
    means = SampleColourMean(rdm_sample)
    stds = SampleColourSD(rdm_sample)
    return means[:3] + stds[:3]

# %%
cropped_img_name = df['file_name_cropped']
print type(cropped_img_name[0])
print cropped_img_name.head()
print len(cropped_img_name)
# Out:
# <type 'str'>
# 0              img_001_anniesfruitybunnies_cropped.png
# 1               img_002_annieshoneybunnies_cropped.png
# 2        img_003_anniescinnamonrollbunnyos_cropped.png
# 3             img_004_anniesorganicbunnyos_cropped.png
# 4    img_005_barbarasbakerypuffinspuffscrunchycocoa...
# Name: file_name_cropped, dtype: object
# 260

# %%
# Print out Sample Colour Mean and Standard Deviation of images background removed (first ten images)
meansSds = []

for i in range(260):
    img_name = '../img/kelvin_cropped/' + cropped_img_name[i]
    
    #Read the image
    alpha_img = cv2.imread(img_name, cv2.IMREAD_UNCHANGED)
    
    # Restructure alpha_img into 1D array
    alpha_img_1D = reform(alpha_img)
    
    # Random Sampling using 0.2 * (Total Pixels) samples
    rdm_sample = random.sample(alpha_img_1D, int(0.2 * len(alpha_img_1D)))
    
    # Sample Mean and standard deviation
    print  str(i+1).zfill(3) + ': ' + str(SampleColourMeanSD(rdm_sample))
    meansSds.append(SampleColourMeanSD(rdm_sample))
# Out:
# 001: [38.82, 78.54, 210.67, 54.15, 86.45, 62.0]
# 002: [51.6, 106.1, 197.4, 46.69, 48.12, 55.06]
# 003: [72.4, 134.5, 194.79, 53.26, 61.92, 40.47]
# 004: [97.13, 76.28, 115.6, 47.43, 71.57, 58.21]
# 005: [104.1, 151.29, 185.99, 48.43, 51.12, 53.53]
# 006: [127.99, 165.81, 197.39, 51.02, 59.16, 55.53]
# 007: [100.23, 143.88, 186.35, 48.68, 49.15, 49.92]
# 008: [112.01, 140.46, 174.33, 45.85, 52.43, 50.18]
# 009: [103.68, 139.38, 176.92, 47.72, 55.58, 55.87]
# 010: [121.3, 151.77, 183.85, 48.48, 49.7, 49.98]
# 011: [111.87, 136.37, 163.2, 46.87, 57.69, 65.06]
# 012: [119.32, 145.65, 171.2, 45.45, 50.81, 57.45]
# 013: [110.32, 141.69, 175.96, 48.17, 52.77, 50.67]
# 014: [111.85, 147.05, 180.42, 47.79, 46.41, 44.98]
# 015: [123.78, 149.21, 177.92, 41.73, 48.18, 52.75]
# 016: [107.16, 120.85, 126.84, 42.4, 42.74, 41.94]
# 017: [108.5, 132.76, 171.93, 58.39, 63.33, 63.99]
# 018: [119.64, 146.17, 177.5, 46.92, 52.03, 50.47]
# 019: [106.71, 138.58, 176.49, 48.3, 53.3, 49.21]
# 020: [122.7, 154.62, 183.52, 43.35, 44.11, 44.55]
# 021: [116.9, 143.3, 172.29, 42.85, 44.97, 50.41]
# 022: [99.19, 142.13, 181.54, 49.15, 54.91, 45.66]
# 023: [119.84, 158.1, 195.46, 43.98, 46.64, 44.99]
# 024: [124.8, 159.3, 190.51, 42.9, 45.77, 46.51]
# 025: [116.53, 150.18, 183.66, 45.22, 52.93, 51.93]
# 026: [171.29, 197.32, 216.11, 80.46, 55.69, 52.13]
# 027: [146.91, 165.26, 197.56, 83.64, 70.48, 58.09]
# 028: [111.16, 158.4, 180.89, 75.15, 66.28, 71.31]
# 029: [162.12, 188.17, 198.76, 86.1, 67.83, 60.8]
# 030: [149.25, 171.0, 179.29, 73.71, 52.49, 41.55]
# 031: [101.99, 137.11, 154.99, 72.96, 62.19, 55.93]
# 078: [162.11, 163.55, 186.88, 85.86, 67.86, 66.04]
# 079: [127.37, 75.38, 154.92, 62.73, 69.98, 78.78]
# 080: [131.87, 183.52, 202.93, 93.34, 64.63, 76.75]
# 081: [112.2, 162.15, 173.51, 82.66, 64.09, 76.84]
# 082: [122.15, 85.75, 151.9, 59.18, 79.77, 58.64]
# 083: [122.92, 125.59, 159.83, 89.17, 82.55, 92.49]
# 084: [76.79, 119.26, 181.31, 77.45, 63.92, 86.39]
# 085: [65.57, 109.64, 190.05, 62.82, 83.65, 69.14]
# 086: [98.59, 132.64, 158.35, 71.29, 81.53, 73.59]
# 087: [134.03, 150.51, 196.62, 74.62, 79.16, 42.4]
# 088: [128.31, 121.54, 163.01, 79.07, 73.91, 54.25]
# 089: [129.06, 150.08, 186.65, 61.61, 71.6, 56.72]
# 090: [48.02, 111.22, 179.59, 60.68, 65.43, 67.14]
# 091: [98.46, 68.79, 125.22, 63.29, 73.43, 75.07]
# 092: [143.45, 121.43, 100.31, 78.37, 68.02, 97.56]
# 093: [135.15, 155.04, 198.23, 94.49, 87.92, 67.13]
# 094: [126.44, 145.17, 163.33, 87.28, 78.76, 83.51]
# 095: [89.48, 120.22, 206.54, 82.17, 63.58, 67.04]
# 096: [47.82, 49.91, 75.95, 64.87, 70.49, 90.7]
# 097: [143.68, 171.88, 187.19, 93.78, 81.81, 74.2]
# 098: [155.84, 181.39, 195.21, 92.27, 75.62, 74.4]
# 099: [157.45, 175.17, 206.71, 94.39, 83.0, 62.16]
# 100: [100.0, 145.3, 109.84, 58.42, 64.16, 88.0]
# 101: [104.21, 120.06, 153.11, 78.35, 74.12, 67.52]
# 102: [125.19, 154.93, 171.22, 90.39, 81.03, 94.55]
# 103: [90.3, 163.94, 210.39, 74.59, 72.8, 67.14]
# 104: [143.89, 124.52, 117.85, 67.85, 66.7, 81.98]
# 105: [140.02, 121.85, 88.3, 62.84, 59.41, 103.45]
# 106: [89.12, 150.74, 177.65, 61.8, 54.76, 94.69]
# 107: [89.14, 149.43, 176.7, 61.87, 54.74, 94.7]
# 108: [97.63, 157.73, 168.45, 74.9, 60.18, 89.73]
# 109: [100.7, 150.28, 219.66, 82.03, 77.03, 47.35]
# 110: [112.05, 133.39, 180.92, 82.97, 92.75, 74.49]
# 111: [110.3, 127.51, 124.43, 78.92, 74.01, 94.54]
# 112: [84.52, 116.61, 159.77, 77.34, 73.42, 63.43]
# 113: [114.68, 115.04, 167.22, 71.29, 77.46, 73.05]
# 114: [90.03, 106.39, 161.4, 73.79, 75.79, 77.44]
# 115: [132.86, 129.8, 127.09, 78.01, 68.64, 103.52]
# 116: [143.8, 139.79, 148.54, 80.05, 75.9, 101.79]
# 117: [53.48, 91.84, 184.52, 63.0, 78.83, 54.9]
# 118: [102.68, 171.33, 181.33, 76.04, 65.29, 71.15]
# 119: [101.68, 193.17, 189.91, 73.03, 55.6, 52.75]
# 120: [124.99, 131.42, 165.73, 79.11, 74.07, 88.09]
# 121: [129.86, 148.88, 159.63, 85.19, 69.42, 90.4]
# 122: [163.82, 156.85, 143.77, 53.05, 51.76, 70.33]
# 169: [190.5, 219.3, 224.78, 82.4, 47.12, 52.53]
# 170: [179.85, 184.33, 205.47, 88.14, 88.59, 65.75]
# 171: [164.43, 166.94, 183.75, 82.4, 74.75, 63.83]
# 172: [197.14, 203.35, 212.24, 82.0, 79.47, 67.17]
# 173: [158.79, 168.71, 196.1, 82.08, 77.51, 56.04]
# 174: [87.86, 130.73, 136.04, 32.84, 37.68, 28.58]
# 175: [148.97, 179.33, 215.34, 95.75, 76.54, 57.42]
# 176: [148.32, 165.79, 191.85, 76.24, 66.1, 49.0]
# 177: [181.21, 205.79, 221.99, 90.45, 62.53, 55.9]
# 178: [155.39, 170.3, 181.43, 84.45, 69.38, 73.93]
# 179: [178.26, 209.93, 211.22, 79.52, 53.33, 60.44]
# 180: [99.89, 121.3, 184.73, 73.2, 79.01, 51.52]
# 181: [115.6, 137.45, 138.54, 71.62, 60.8, 62.92]
# 182: [74.15, 105.97, 176.51, 46.7, 51.42, 51.28]
# 183: [128.45, 171.09, 191.89, 77.33, 69.04, 63.85]
# 184: [36.27, 93.55, 116.95, 50.0, 66.21, 78.92]
# 185: [97.66, 131.28, 129.08, 66.22, 70.5, 77.42]
# 186: [129.5, 144.68, 151.55, 65.6, 60.66, 71.67]
# 187: [101.5, 157.11, 162.75, 71.17, 67.21, 72.64]
# 188: [123.88, 148.38, 165.53, 71.5, 72.48, 76.52]
# 189: [122.97, 133.3, 145.87, 56.19, 75.72, 90.74]
# 190: [96.16, 94.4, 166.88, 63.23, 80.96, 51.47]
# 191: [111.28, 144.92, 193.59, 76.48, 73.12, 56.15]
# 192: [92.8, 134.37, 169.79, 49.56, 71.74, 80.63]
# 193: [79.82, 69.2, 117.19, 35.97, 37.34, 34.84]
# 194: [77.12, 134.54, 177.16, 54.27, 73.83, 80.11]
# 195: [48.28, 105.68, 149.17, 68.3, 58.66, 56.09]
# 196: [156.64, 178.61, 198.42, 75.22, 58.21, 49.4]
# 197: [131.7, 129.35, 112.89, 60.57, 66.21, 93.36]
# 198: [132.44, 188.65, 197.45, 71.45, 58.28, 79.43]
# 199: [147.72, 137.03, 116.16, 59.2, 53.4, 86.76]
# 200: [53.52, 147.5, 217.36, 68.53, 47.03, 50.85]
# 201: [95.29, 147.65, 169.98, 84.98, 66.86, 83.18]
# 202: [178.01, 189.47, 212.97, 77.35, 71.37, 44.52]
# 203: [162.93, 160.27, 180.91, 60.86, 69.27, 53.22]
# 204: [117.81, 171.82, 218.32, 89.63, 69.76, 54.02]
# 205: [125.33, 159.24, 174.67, 95.91, 76.51, 89.05]
# 206: [117.31, 145.87, 206.01, 86.04, 80.76, 44.11]
# 207: [81.35, 111.46, 188.42, 88.18, 80.46, 52.42]
# 208: [91.49, 134.63, 189.29, 98.78, 80.41, 58.24]
# 209: [81.8, 139.43, 168.13, 95.13, 78.68, 80.49]
# 210: [79.72, 123.58, 147.13, 76.45, 63.93, 56.53]
# 211: [110.67, 179.25, 215.13, 78.54, 64.67, 62.69]
# 212: [89.34, 152.24, 181.04, 75.81, 60.33, 73.36]
# 213: [52.04, 95.32, 137.98, 59.33, 67.02, 63.21]
# 214: [76.23, 110.0, 185.05, 65.14, 81.74, 72.62]
# 215: [69.15, 121.86, 193.46, 76.54, 67.87, 62.21]
# 216: [121.83, 146.24, 130.11, 85.21, 69.12, 106.18]
# 217: [122.91, 94.94, 118.85, 70.94, 81.14, 77.01]
# 218: [115.06, 143.58, 151.82, 64.12, 69.93, 97.72]
# 219: [132.87, 174.76, 218.92, 85.49, 62.18, 35.68]
# 220: [99.49, 122.86, 196.05, 72.72, 83.92, 53.28]
# 221: [133.63, 155.39, 186.61, 82.64, 79.29, 61.09]
# 222: [92.63, 121.15, 186.18, 75.18, 82.95, 66.83]
# 223: [92.74, 147.42, 185.1, 91.35, 61.63, 46.54]
# 224: [72.85, 78.53, 207.93, 61.65, 70.83, 32.3]
# 225: [71.89, 140.05, 229.24, 59.18, 49.05, 34.78]
# 226: [75.65, 81.73, 208.43, 61.74, 70.99, 32.27]
# 227: [69.9, 88.67, 144.95, 63.83, 65.66, 52.07]
# 228: [210.3, 191.31, 149.9, 51.59, 47.56, 76.23]
# 229: [54.13, 127.32, 189.58, 70.66, 63.65, 67.97]
# 230: [108.91, 109.85, 124.77, 56.52, 50.57, 43.16]
# 231: [138.78, 151.34, 172.03, 84.65, 68.27, 39.09]
# 232: [127.69, 145.03, 177.76, 88.04, 69.41, 34.28]
# 233: [137.32, 162.26, 200.6, 90.11, 73.58, 47.4]
# 234: [136.73, 163.33, 206.44, 90.88, 72.39, 34.71]
# 235: [164.92, 186.65, 213.29, 80.5, 63.8, 36.39]
# 236: [136.14, 163.4, 207.57, 101.61, 84.16, 40.61]
# 237: [161.45, 177.01, 207.95, 82.7, 71.78, 42.34]
# 238: [148.4, 165.55, 200.14, 90.43, 77.62, 50.26]
# 239: [157.05, 174.14, 198.28, 86.03, 68.91, 50.84]
# 240: [155.17, 169.22, 203.66, 83.01, 73.65, 48.08]
# 241: [150.91, 179.15, 199.69, 88.62, 69.87, 50.7]
# 242: [153.78, 177.14, 213.86, 86.26, 71.02, 33.09]
# 243: [58.58, 96.03, 146.13, 58.46, 58.8, 74.58]
# 244: [98.6, 145.27, 177.02, 74.78, 67.73, 76.32]
# 245: [110.17, 118.03, 173.97, 70.84, 72.24, 69.66]
# 246: [71.83, 112.33, 143.6, 68.57, 69.28, 63.24]
# 247: [116.35, 120.73, 112.14, 70.96, 73.45, 79.76]
# 248: [113.31, 154.26, 180.55, 55.53, 83.14, 90.38]
# 249: [96.97, 112.24, 143.28, 58.43, 64.1, 68.11]
# 250: [155.58, 166.6, 171.23, 83.17, 67.51, 66.64]
# 251: [107.76, 103.79, 109.16, 64.93, 75.06, 80.0]
# 252: [138.44, 134.46, 156.75, 77.66, 92.48, 85.84]
# 253: [112.79, 127.94, 131.09, 65.13, 71.42, 76.07]
# 254: [111.2, 99.98, 121.4, 58.37, 68.26, 67.26]
# 255: [71.48, 83.27, 156.15, 57.49, 61.14, 75.57]
# 256: [160.03, 131.94, 88.89, 62.54, 58.67, 98.71]
# 257: [93.08, 124.12, 178.9, 58.5, 60.99, 85.93]
# 258: [89.09, 120.0, 166.94, 65.6, 61.82, 74.02]
# 259: [147.17, 166.01, 201.38, 90.73, 73.27, 46.44]
# 260: [89.27, 106.51, 127.87, 51.32, 39.41, 38.1]

# %%
# Original Colour Mean and Standard Deviation of images with background removed (first five images)
# Just for comparison (very close to the result above, but much slower)

# for i in range(5):
#     img_name = '../img/kelvin_cropped/' + cropped_img_name[i]
#    
#    #Read the image
#    alpha_img = cv2.imread(img_name, cv2.IMREAD_UNCHANGED)
#    
#    # Sample Mean and standard deviation
#    print colourMeanSD(alpha_img)
# Out:
# [38.74, 74.63, 207.51, 54.19, 86.31, 62.0]
# [52.21, 106.96, 197.1, 46.75, 48.19, 54.96]
# [66.78, 125.77, 190.6, 52.9, 61.23, 40.12]
# [94.63, 77.47, 115.95, 47.46, 71.49, 58.16]
# [106.87, 151.4, 185.39, 48.51, 51.11, 53.43]

# %%
def genColourMeanSD(row):
    return meansSds[row['index'] - 1]

# %%
df['sample_mean_sd'] = df.apply(genColourMeanSD, axis = 1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  serving_size  \
# 0                  1                  85                   120            29
# 1                  1                  90                   110            29
# 2                  1                  85                   120            29
# 3                  1                 110                   120            29
# 4                  3                  80                   120            30
#
#    index                                                url  \
# 0      1  http://cerealfacts.org/cereal_nutrition_scores...
# 1      2  http://cerealfacts.org/cereal_nutrition_scores...
# 2      3  http://cerealfacts.org/cereal_nutrition_scores...
# 3      4  http://cerealfacts.org/cereal_nutrition_scores...
# 4      5  http://cerealfacts.org/cereal_nutrition_scores...
#
#                                    file_name_cropped  \
# 0            img_001_anniesfruitybunnies_cropped.png
# 1             img_002_annieshoneybunnies_cropped.png
# 2      img_003_anniescinnamonrollbunnyos_cropped.png
# 3           img_004_anniesorganicbunnyos_cropped.png
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...
#
#                                  sample_mean_sd
# 0    [38.82, 78.54, 210.67, 54.15, 86.45, 62.0]
# 1     [51.6, 106.1, 197.4, 46.69, 48.12, 55.06]
# 2    [72.4, 134.5, 194.79, 53.26, 61.92, 40.47]
# 3    [97.13, 76.28, 115.6, 47.43, 71.57, 58.21]
# 4  [104.1, 151.29, 185.99, 48.43, 51.12, 53.53]

# %%
for i in range(5):
    print meansSds[i]
# Out:
# [38.82, 78.54, 210.67, 54.15, 86.45, 62.0]
# [51.6, 106.1, 197.4, 46.69, 48.12, 55.06]
# [72.4, 134.5, 194.79, 53.26, 61.92, 40.47]
# [97.13, 76.28, 115.6, 47.43, 71.57, 58.21]
# [104.1, 151.29, 185.99, 48.43, 51.12, 53.53]

# %%
df.to_csv('../data/data_withMeanSD.csv')
