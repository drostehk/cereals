# %%
# Ref : http://blog.zeevgilovitz.com/detecting-dominant-colours-in-python/

from PIL import Image
import random
import numpy as np
import pandas as pd
import itertools
import webcolors

# %%
df = pd.read_csv('../data/data_updated.csv')
df = df.drop('Unnamed: 0', 1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#          ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 0        ...          35.58   71.37  208.29  54.28  86.32  62.01
# 1        ...          53.31  107.21  195.62  46.53  48.07  54.99
# 2        ...          65.40  123.12  191.40  52.63  60.91  40.15
# 3        ...          95.78   78.63  115.69  47.58  71.51  58.18
# 4        ...         108.41  153.04  186.66  48.37  51.09  53.44
#
#    most_fre_color  most_fre_color_count  \
# 0         #e70000                   256
# 1         #d8501e                   256
# 2         #bd582a                   256
# 3         #581680                  1272
# 4         #ffffff                   681
#
#                                            file_name  most_domin_color
# 0                    img_001_anniesfruitybunnies.jpg             white
# 1                     img_002_annieshoneybunnies.jpg             brown
# 2              img_003_anniescinnamonrollbunnyos.jpg             brown
# 3                   img_004_anniesorganicbunnyos.jpg             brown
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...              grey
#
# [5 rows x 28 columns]

# %%
def gen_file_name(row):
    file_name = row.cover_image.split('/')[len(row.cover_image.split('/'))-1]
    file_name = 'img_' + str(row['index']).zfill (3) + '_' + (file_name).lower()
    return(file_name)

# %%
df['file_name'] = df.apply(gen_file_name, axis=1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#          ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 0        ...          35.58   71.37  208.29  54.28  86.32  62.01
# 1        ...          53.31  107.21  195.62  46.53  48.07  54.99
# 2        ...          65.40  123.12  191.40  52.63  60.91  40.15
# 3        ...          95.78   78.63  115.69  47.58  71.51  58.18
# 4        ...         108.41  153.04  186.66  48.37  51.09  53.44
#
#    most_fre_color  most_fre_color_count  \
# 0         #e70000                   256
# 1         #d8501e                   256
# 2         #bd582a                   256
# 3         #581680                  1272
# 4         #ffffff                   681
#
#                                            file_name  most_domin_color
# 0                    img_001_anniesfruitybunnies.jpg             white
# 1                     img_002_annieshoneybunnies.jpg             brown
# 2              img_003_anniescinnamonrollbunnyos.jpg             brown
# 3                   img_004_anniesorganicbunnyos.jpg             brown
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...              grey
#
# [5 rows x 28 columns]

# %%
# K-mean Clustering

# Class : Cluster
class Cluster(object):

    def __init__(self):
        self.pixels = []
        self.lastpixels = []
        self.centroid = None

    def addPoint(self, pixel):
        self.pixels.append(pixel)
        
    def pixelCount(self):
        return len(self.lastpixels)

    def setNewCentroid(self):

        R = [colour[0] for colour in self.pixels]
        G = [colour[1] for colour in self.pixels]
        B = [colour[2] for colour in self.pixels]

        R = sum(R) / (len(R) + 1)
        G = sum(G) / (len(G) + 1)
        B = sum(B) / (len(B) + 1)
        
        self.centroid = (R, G, B)
        self.lastpixels = self.pixels
        self.pixels = []

        return self.centroid

# %%
# Class : Kmeans
class Kmeans(object):

    def __init__(self, k=3, max_iterations=5, min_distance=2.0, size=300):
        self.k = k
        self.max_iterations = max_iterations
        self.min_distance = min_distance
        self.size = (size, size + 1)

    def run(self, image):
        self.image = image
        self.image.thumbnail(self.size)
        self.pixels = np.array(image.getdata(), dtype=np.uint8)

        self.clusters = [None for i in range(self.k)]
        self.oldClusters = None

        randomPixels = random.sample(self.pixels, self.k)

        for idx in range(self.k):
            self.clusters[idx] = Cluster()
            self.clusters[idx].centroid = randomPixels[idx]

        iterations = 0

        while self.shouldExit(iterations) is False:

            self.oldClusters = [cluster.centroid for cluster in self.clusters]

            # print iterations

            for pixel in self.pixels:
                self.assignClusters(pixel)

            for cluster in self.clusters:
                cluster.setNewCentroid()

            iterations += 1
        
        pixelCounts = [cluster.pixelCount() for cluster in self.clusters]
        
        clusters_centroid = [cluster.centroid for cluster in self.clusters]
        
        return pixelCounts

    def assignClusters(self, pixel):
        shortest = float('Inf')
        for cluster in self.clusters:
            distance = self.calcDistance(cluster.centroid, pixel)
            if distance < shortest:
                shortest = distance
                nearest = cluster

        nearest.addPoint(pixel)

    def calcDistance(self, a, b):

        result = np.sqrt(sum((a - b) ** 2))
        return result

    def shouldExit(self, iterations):

        if self.oldClusters is None:
            return False

        for idx in range(self.k):
            dist = self.calcDistance(
                np.array(self.clusters[idx].centroid),
                np.array(self.oldClusters[idx])
            )
            if dist < self.min_distance:
                return True

        if iterations <= self.max_iterations:
            return False

        return True

    # The remaining methods are used for debugging
    
    def showImage(self):
        self.image.show()

    def showCentroidColours(self):

        for cluster in self.clusters:
            image = Image.new("RGB", (200, 200), cluster.centroid)
            image.show()

    def showClustering(self):

        localPixels = [None] * len(self.image.getdata())

        for idx, pixel in enumerate(self.pixels):
                shortest = float('Inf')
                for cluster in self.clusters:
                    distance = self.calcDistance(
                        cluster.centroid,
                        pixel
                    )
                    if distance < shortest:
                        shortest = distance
                        nearest = cluster

                localPixels[idx] = nearest.centroid

        w, h = self.image.size
        localPixels = np.asarray(localPixels)\
            .astype('uint8')\
            .reshape((h, w, 3))

        colourMap = Image.fromarray(localPixels)
        colourMap.show()
        
    def printCentroidColoursHexCode(self):
        hexcodes = []
        for cluster in self.clusters:
            hexcode = '#'+''.join(map(chr, cluster.centroid)).encode('hex')
            hexcodes.append(hexcode)
            # print cluster.centroid, hexcode
          
        print hexcodes
        
        return hexcodes
    
    def printCentroidColoursRGB(self):
        RGBs = []
        for cluster in self.clusters:
            RGBs.append(cluster.centroid)
        
        print RGB
        
        return RGB

# %%
img_name = df['file_name']

# %%
hexcodes_dominant_color = []
pixels_num_color = []

for i in range(260):
    img = Image.open('../img/' + img_name[i])
    
    k = Kmeans()
    pixels_num = k.run(img)
    
    hexcode = k.printCentroidColoursHexCode()
    print pixels_num
    
    hexcodes_dominant_color.append(hexcode)
    pixels_num_color.append(pixels_num)
# Out:
# ['#fdfcfc', '#c7a43e', '#d3150f']
# [40663, 16677, 32660]
# ['#d0bc7a', '#555636', '#da5b23']
# [10427, 9301, 42880]
# ['#f0e3ae', '#bd642e', '#6a753c']
# [16480, 40899, 5530]
# ['#756538', '#c4af5a', '#4e186f']
# [12801, 16400, 34912]
# ['#48374a', '#c18d49', '#d6bf97']
# [8205, 23331, 29266]
# ['#623849', '#cea76e', '#e7d7c0']
# [10861, 30900, 18439]
# ['#623c3a', '#ccb28f', '#c78841']
# [9466, 31532, 16493]
# ['#5e3436', '#b79269', '#d4bc9f']
# [11190, 25553, 21049]
# ['#512f34', '#d2b995', '#bc8c59']
# [10779, 26146, 20265]
# ['#dbcab3', '#583842', '#c0996d']
# [14855, 7836, 34499]
# ['#463540', '#e0d0bb', '#ba9872']
# [17099, 12825, 32082]
# ['#ceb593', '#3e3749', '#a8855f']
# [31206, 9281, 16402]
# ['#593430', '#b68659', '#cfb595']
# [10681, 18555, 28556]
# ['#d7c5ad', '#bc986f', '#6e4835']
# [16024, 31044, 10423]
# ['#d5bea2', '#4d4050', '#b7916c']
# [21447, 8986, 27359]
# ['#6d5f4d', '#737877', '#a6a693']
# [34812, 12487, 20426]
# ['#d0b49b', '#391a18', '#b37652']
# [45441, 17451, 26204]
# ['#b89673', '#5f3a38', '#d6c0a7']
# [27028, 11519, 18944]
# ['#c2a07a', '#6d3c2f', '#fdfdfc']
# [38607, 15608, 35785]
# ['#c4a57e', '#fdfcfa', '#69493c']
# [44151, 37505, 8344]
# ['#78594e', '#c6a67f', '#fdfdfc']
# [15808, 38442, 35750]
# ['#c6a467', '#8b4c38', '#f3ede1']
# [33860, 19703, 13259]
# ['#9d6645', '#fefbf7', '#cfae82']
# [15352, 34637, 40011]
# ['#c7a77a', '#fcfbfa', '#613c45']
# [48675, 33862, 7463]
# ['#c7a37a', '#fdfcfa', '#5c3534']
# [45783, 32531, 11686]
# ['#fcfbfb', '#cab79a', '#ae8449']
# [36586, 13580, 17559]
# ['#bbbeb5', '#b9542d', '#f7f8f7']
# [18685, 16657, 54658]
# ['#fafaf7', '#c8a55d', '#504f33']
# [50769, 25798, 13433]
# ['#b4a370', '#f8f7f1', '#715a34']
# [19204, 32034, 14681]
# ['#896a38', '#e2e5e5', '#b8b5a2']
# [14327, 28725, 12934]
# ['#f0f0ec', '#4c341b', '#a2884a']
# [59544, 10800, 19656]
# ['#c2b9a0', '#7c6c59', '#f5f5f4']
# [16694, 15456, 57850]
# ['#b8b08b', '#856d3b', '#eaebe5']
# [14604, 16756, 31850]
# ['#836e49', '#c4c5bd', '#f3f5f6']
# [18962, 17034, 54004]
# ['#967540', '#c9b996', '#fcfbf9']
# [17142, 13762, 32306]
# ['#dadad8', '#a99d7c', '#7e562f']
# [34015, 9683, 24027]
# ['#e1e7e8', '#948945', '#bcbdab']
# [28182, 16481, 15236]
# ['#f9f8f4', '#6a4f37', '#b69c6b']
# [33835, 11728, 20356]
# ['#c16b59', '#f4f3f0', '#59532a']
# [22160, 34843, 8615]
# ['#cb933a', '#c0c0b9', '#f2f6f8']
# [19521, 16847, 53632]
# ['#ab804a', '#f6f5f3', '#345723']
# [18625, 60912, 10463]
# ['#90aac9', '#f3f9fb', '#14477c']
# [15141, 48122, 26737]
# ['#83914c', '#d9cda8', '#149365']
# [28211, 12922, 19669]
# ['#c09647', '#f4e6a4', '#2b71ae']
# [17163, 39944, 10317]
# ['#eee374', '#811f1b', '#d87a3e']
# [22674, 20922, 16604]
# ['#f8f6e4', '#7292b7', '#1f2c6f']
# [37146, 27907, 24947]
# ['#c5964c', '#edd8d0', '#d5121c']
# [17950, 13253, 30803]
# ['#6e524b', '#b0a3a6', '#f4f4f3']
# [18974, 19255, 51771]
# ['#e5d6b3', '#1092cd', '#47366b']
# [19928, 17774, 30324]
# ['#ead69c', '#562e4e', '#000000']
# [80594, 9406, 0]
# ['#f2f2f2', '#5f3d4c', '#a28e94']
# [56743, 7497, 25760]
# ['#f3efe7', '#d4994e', '#444988']
# [29173, 23693, 15160]
# ['#c29541', '#60443e', '#dad1b3']
# [25614, 20451, 23165]
# ['#b9d1d6', '#a5764f', '#4d302a']
# [12710, 23581, 31434]
# ['#7d311e', '#dbdccf', '#6d8182']
# [35949, 10298, 15458]
# ['#a2412e', '#f7f6f6', '#9f9ca0']
# [19345, 49813, 20842]
# ['#967535', '#4391b2', '#eeeeda']
# [24321, 6350, 28024]
# ['#a73011', '#96937a', '#f9f9f6']
# [32764, 19937, 37299]
# ['#f6f3f2', '#9b7767', '#a52215']
# [60084, 21317, 8599]
# ['#e9ecec', '#328ec4', '#b44938']
# [27387, 17865, 13443]
# ['#a86f61', '#d9c088', '#f6f6f5']
# [19003, 16428, 54569]
# ['#7b5540', '#d49b61', '#dfd2d7']
# [19529, 17238, 32463]
# ['#256770', '#dabd8d', '#ca2249']
# [9356, 19417, 34437]
# ['#366788', '#c6a06c', '#62361a']
# [5043, 26561, 35218]
# ['#f6f7ee', '#3f141c', '#a1616b']
# [23474, 28905, 16550]
# ['#9ca3ac', '#f6f7f7', '#3b4a6f']
# [15359, 50812, 23829]
# ['#894f3f', '#93b09c', '#f5f6f4']
# [25697, 15993, 28744]
# ['#dfb55b', '#561c0e', '#945021']
# [23567, 25582, 16168]
# ['#b4bbb4', '#f6f7f6', '#66557b']
# [5642, 17332, 7651]
# ['#d19776', '#f8f5f3', '#6c435d']
# [15174, 32976, 17167]
# ['#595248', '#b8b08d', '#f0f0ef']
# [18877, 14767, 34081]
# ['#9e9fc8', '#ddae47', '#4a3d48']
# [19206, 24873, 20034]
# ['#f4e3c1', '#b06436', '#269aca']
# [30624, 30138, 6662]
# ['#7f888c', '#f5f0e6', '#3c2b37']
# [24094, 55081, 10825]
# ['#f4ebcd', '#71665f', '#e8b650']
# [28816, 18992, 20218]
# ['#495b66', '#f2ebcc', '#de9244']
# [14928, 28525, 23068]
# ['#a6575b', '#1898cf', '#f5e0c2']
# [27865, 6912, 32948]
# ['#f8f7f6', '#b5582d', '#a3b7cc']
# [45329, 19397, 25274]
# ['#4c1f55', '#af3372', '#e18ab1']
# [27825, 14229, 27176]
# ['#edebe7', '#475e90', '#e9ba2f']
# [22135, 14539, 31051]
# ['#526f93', '#dbab26', '#e7e5cb']
# [21820, 26609, 20199]
# ['#8f2d6f', '#dcd7b1', '#42394f']
# [37109, 14907, 9388]
# ['#fafaf9', '#df853b', '#423e85']
# [43354, 23569, 23077]
# ['#e2791e', '#f9f9f7', '#264187']
# [31689, 47159, 11152]
# ['#fbf9f5', '#e47337', '#5d4530']
# [42409, 34748, 12843]
# ['#5a342c', '#c9b46f', '#fbf9f7']
# [24059, 26457, 39484]
# ['#a63538', '#e1ddd1', '#baa369']
# [23134, 30518, 15879]
# ['#d5cdd2', '#831c1d', '#000000']
# [33004, 6996, 0]
# ['#e3d6b3', '#7e3c50', '#b7906b']
# [28466, 19085, 20776]
# ['#ecc8a2', '#57321e', '#000000']
# [77779, 12221, 0]
# ['#451e5a', '#b64540', '#efe8e5']
# [32628, 20115, 15283]
# ['#ae473b', '#dbeaed', '#0980b9']
# [22491, 18709, 24719]
# ['#7a343b', '#f4ece4', '#e09947']
# [20174, 26029, 14599]
# ['#dbcbc0', '#664133', '#000000']
# [78888, 11112, 0]
# ['#3094bd', '#dd592a', '#edede8']
# [6054, 45317, 10033]
# ['#100b0e', '#d8baa8', '#a74034']
# [42887, 11626, 11707]
# ['#3d2210', '#c1a75b', '#ebeae7']
# [17809, 20861, 51330]
# ['#cea673', '#655331', '#faf8f4']
# [14480, 15644, 29775]
# ['#d09e6c', '#7e3a2b', '#f8f5f2']
# [15792, 15740, 27163]
# ['#3ca45d', '#eee9db', '#774737']
# [22665, 20033, 15395]
# ['#fbf9f6', '#6f4031', '#ae937c']
# [43114, 30341, 16545]
# ['#bd4727', '#319957', '#f4f3ee']
# [17472, 12701, 35445]
# ['#e5dbc1', '#f1c55a', '#9f393c']
# [12380, 20270, 8915]
# ['#f9f6f1', '#a58d6d', '#38518b']
# [14898, 17362, 26736]
# ['#f1f0ef', '#075b98', '#b6884d']
# [17439, 26950, 13704]
# ['#edc269', '#115c80', '#c37831']
# [34054, 15873, 15691]
# ['#125c7f', '#edc46d', '#c87e31']
# [16006, 31821, 17791]
# ['#da9d2d', '#206f85', '#bfcec5']
# [35516, 16640, 11054]
# ['#fafaf7', '#d6bb62', '#e1391f']
# [51363, 24687, 13950]
# ['#812a33', '#f3f0ea', '#d4b15c']
# [24470, 24638, 14704]
# ['#c78f3b', '#275168', '#faf9f7']
# [19354, 24523, 46123]
# ['#763a1a', '#faf9f7', '#c8a06d']
# [29429, 45284, 15287]
# ['#5f4f74', '#d3d3c1', '#d35036']
# [23615, 16237, 17940]
# ['#cb3c2b', '#d5cebc', '#45594d']
# [25096, 15045, 20059]
# ['#c96731', '#dcdcd8', '#0f5d8a']
# [17323, 16656, 25920]
# ['#ca6a3e', '#155893', '#f4f6f6']
# [19581, 23170, 47249]
# ['#b32817', '#fbfbfa', '#bcab4c']
# [25296, 47761, 16943]
# ['#6e6f3f', '#ddb248', '#edeecd']
# [18114, 19456, 25038]
# ['#cac16f', '#a5ad30', '#eeefda']
# [11183, 34776, 12736]
# ['#2e6383', '#eaeae6', '#cf5c3e']
# [14891, 26229, 22391]
# ['#d29847', '#2d4a6c', '#e5e7e8']
# [23876, 20019, 20820]
# ['#cbcdc4', '#5e86b1', '#555c61']
# [32607, 17666, 12335]
# ['#3b4a3a', '#f2f3f1', '#c29573']
# [18899, 21756, 23157]
# ['#3e4947', '#f2f3f2', '#ab8d74']
# [21263, 21317, 20028]
# ['#5c5963', '#f5f5f6', '#d38e9d']
# [16268, 19923, 24611]
# ['#faf8f2', '#0c4c6d', '#597a93']
# [63456, 5640, 20904]
# ['#9b9a79', '#e9eced', '#444971']
# [21165, 20310, 31367]
# ['#422f2f', '#857a66', '#d7d9dc']
# [25872, 17066, 17864]
# ['#d9d8ce', '#a2792d', '#2b689f']
# [26691, 27330, 12500]
# ['#166d7f', '#dc8c3f', '#e1d9c5']
# [12762, 25200, 26753]
# ['#f6f4f4', '#ba5131', '#711e0e']
# [60102, 22852, 7046]
# ['#d59b5a', '#f0e4db', '#c5173c']
# [8107, 27752, 27050]
# ['#f9f9f8', '#7f8694', '#562939']
# [48757, 23639, 17604]
# ['#f5f3f0', '#ba8150', '#5a173e']
# [18707, 19574, 22521]
# ['#805d53', '#d9d7cf', '#5babcb']
# [14381, 28519, 20009]
# ['#f6f5f3', '#233367', '#88637f']
# [53221, 5688, 31091]
# ['#e4e5e4', '#1c6089', '#a07152']
# [18293, 29193, 17229]
# ['#244c71', '#885b40', '#bdb49d']
# [11528, 15630, 27925]
# ['#bbbfc5', '#826b51', '#fafbfc']
# [16755, 18287, 54958]
# ['#f4ede7', '#955c2f', '#c7ab8b']
# [32685, 20418, 10107]
# ['#774422', '#d6d4ca', '#16acd5']
# [21230, 19817, 22163]
# ['#5d6896', '#dad8e0', '#c13c42']
# [19476, 29210, 14524]
# ['#f9f6f2', '#a44435', '#bca28d']
# [25417, 20545, 17850]
# ['#f2e0d2', '#d88348', '#48636b']
# [30793, 26736, 5380]
# ['#bb4a44', '#f6f3f7', '#b6a0b9']
# [16444, 25820, 20645]
# ['#c85442', '#e9eef3', '#67aace']
# [14968, 32300, 15641]
# ['#f5edee', '#ab1810', '#ba8680']
# [64385, 13647, 11968]
# ['#c75d54', '#f5f5f5', '#c6c7c6']
# [11668, 44485, 11572]
# ['#bf9e72', '#f5e5c8', '#b03a3a']
# [13454, 31920, 18438]
# ['#d5d0c9', '#a65640', '#4382af']
# [37512, 22628, 7585]
# ['#6490a3', '#7f552b', '#d5e4df']
# [16092, 26841, 22685]
# ['#fcfbfa', '#b8741f', '#c7b18d']
# [22390, 11357, 6253]
# ['#d26140', '#f5f5f3', '#672f12']
# [11815, 24813, 3372]
# ['#624b5c', '#fcfaf8', '#d7ac68']
# [30004, 39505, 20491]
# ['#bda381', '#f8f5f0', '#5e381c']
# [12721, 27091, 11960]
# ['#c1986c', '#eeedea', '#6c2812']
# [11460, 24240, 7161]
# ['#dcb88a', '#9e6338', '#fbfaf7']
# [19265, 18766, 37821]
# ['#7e563c', '#f4f3f3', '#c7ac92']
# [22431, 51771, 15798]
# ['#c8a361', '#f2f0eb', '#4b5b34']
# [19969, 53415, 6682]
# ['#eedbca', '#3d5e36', '#000000']
# [61020, 4598, 0]
# ['#c5ab86', '#ac4a25', '#e7e6dd']
# [12478, 17747, 36296]
# ['#dcaa50', '#f5f7f6', '#804623']
# [18225, 34692, 6380]
# ['#fbf9f7', '#5f1b25', '#c9a27c']
# [38622, 13934, 12159]
# ['#faf7ed', '#b27c5a', '#77131c']
# [23516, 12439, 28158]
# ['#faf8f7', '#c39066', '#684330']
# [69620, 14119, 6261]
# ['#b4aaa9', '#694d37', '#f9f9fa']
# [9847, 10801, 44672]
# ['#faf9f8', '#8f4e23', '#b5b4a9']
# [36628, 11300, 11670]
# ['#89612f', '#e3e3e3', '#b6a587']
# [19758, 32612, 9335]
# ['#e7c786', '#a38f3a', '#fdfdfb']
# [9873, 10324, 69803]
# ['#faf9f6', '#8c313a', '#898570']
# [38792, 11183, 8118]
# ['#bca8a4', '#613e31', '#f1f2f3']
# [13021, 17411, 59568]
# ['#f6f4f3', '#51362f', '#aa8475']
# [41556, 8377, 8762]
# ['#fafaf9', '#c1a895', '#8b5142']
# [44898, 11994, 16552]
# ['#fdfdfd', '#6d214a', '#8a8858']
# [41400, 4761, 43839]
# ['#fcfbfa', '#db994f', '#713e27']
# [63118, 17944, 8938]
# ['#c1ae9f', '#f8f8f7', '#99684c']
# [10512, 55738, 23750]
# ['#fcfbf9', '#356038', '#cd8e4d']
# [54646, 3752, 17454]
# ['#4d4837', '#ca9c36', '#e4dad8']
# [17936, 7105, 39674]
# ['#f0efdf', '#4f6334', '#000000']
# [84775, 5225, 0]
# ['#ebe8dd', '#a78165', '#732316']
# [17743, 10038, 23543]
# ['#4b4b31', '#c8c8cb', '#8c8b63']
# [18810, 20216, 21174]
# ['#cf683b', '#c6ad93', '#783e2f']
# [30727, 14611, 21183]
# ['#fbfaf7', '#755831', '#d4ba7a']
# [50186, 17046, 22768]
# ['#41160b', '#3a6e21', '#c08c34']
# [20357, 12713, 21712]
# ['#77815c', '#313729', '#dbd1a6']
# [18321, 21478, 19799]
# ['#4b7076', '#b5896c', '#f5f4ee']
# [16688, 21573, 18929]
# ['#f3f2eb', '#c1ae5b', '#63643b']
# [20696, 18275, 18219]
# ['#f6f4f0', '#be9c6c', '#585143']
# [21068, 20028, 16094]
# ['#f8f7ef', '#1b3c66', '#b68a61']
# [48691, 17335, 23974]
# ['#953c33', '#f7f3ee', '#49291e']
# [31528, 52185, 6287]
# ['#d0a27b', '#fcfaf5', '#9e522e']
# [11463, 51294, 27243]
# ['#fbf8ed', '#483239', '#daab65']
# [15453, 15594, 24939]
# ['#834633', '#5a2d4f', '#997f84']
# [22978, 33209, 11538]
# ['#fdf9ee', '#5a351b', '#e5b262']
# [14944, 17225, 23817]
# ['#8d560c', '#856543', '#faf8f4']
# [25620, 9724, 32080]
# ['#f9fafb', '#cbbfb5', '#ab7846']
# [53333, 21793, 14874]
# ['#1f527e', '#bc9359', '#f8f9f5']
# [29044, 18064, 42892]
# ['#d9b061', '#faf9f0', '#257342']
# [23141, 58335, 8524]
# ['#1475b9', '#dbd3c7', '#8c6e57']
# [14547, 34481, 15085]
# ['#e89721', '#8e6b33', '#fdfcfb']
# [19391, 6853, 41256]
# ['#34729e', '#d49725', '#f8f9f7']
# [15872, 34569, 39559]
# ['#bda567', '#f1f1f2', '#a03034']
# [8119, 72809, 9072]
# ['#f5f3f2', '#b7a4a0', '#632a43']
# [52239, 9413, 5848]
# ['#f6f5f2', '#e6be6c', '#c37421']
# [45349, 13623, 31028]
# ['#e7e9e2', '#ce8922', '#295d7f']
# [24031, 23170, 13601]
# ['#ece9e6', '#a43932', '#e9a753']
# [22602, 18951, 16540]
# ['#d79236', '#9e211a', '#f3f2f5']
# [17373, 23229, 49398]
# ['#f6f3ea', '#ebaa3c', '#575f2e']
# [45745, 32184, 12071]
# ['#d9c589', '#fcfcfb', '#8b8a39']
# [8315, 57542, 15743]
# ['#9c9175', '#7d5820', '#dfe3e5']
# [13437, 33105, 22387]
# ['#65432e', '#eee6cd', '#eeb83e']
# [9734, 24317, 26751]
# ['#f6f6f1', '#cfa130', '#335183']
# [46536, 32504, 10960]
# ['#a87b39', '#ded1c1', '#4d1f16']
# [24149, 13014, 21532]
# ['#e4c870', '#4f4f4e', '#cd2d2d']
# [22628, 16419, 24163]
# ['#ebdfd4', '#b9621f', '#86858a']
# [15717, 39678, 7815]
# ['#e2ab1d', '#d4d1cc', '#125e8d']
# [18542, 17299, 24961]
# ['#dbcebb', '#1186c5', '#5a2951']
# [16065, 5491, 35634]
# ['#ece6cc', '#15456b', '#c08d46']
# [18554, 16791, 21845]
# ['#f7f4f0', '#d58d44', '#7f3724']
# [59281, 26788, 3931]
# ['#db9662', '#f1e9d9', '#9b292b']
# [16818, 19346, 21327]
# ['#f6f5f3', '#733729', '#d8b88c']
# [51354, 18895, 19751]
# ['#f1eada', '#d98d4f', '#792521']
# [17696, 18659, 20835]
# ['#d29c13', '#edebeb', '#783616']
# [18728, 61100, 10172]
# ['#f4e3d3', '#b76f59', '#cd2527']
# [15071, 8858, 39582]
# ['#f3973b', '#c96037', '#f8f0e4']
# [31537, 19813, 13064]
# ['#ca2628', '#c77d60', '#f4e6d9']
# [40825, 8393, 14293]
# ['#eee6d7', '#793728', '#af7755']
# [12872, 36920, 9505]
# ['#acc0c5', '#f1f7f9', '#3e8eb6']
# [18076, 51672, 20252]
# ['#fafaf8', '#733b34', '#e4951b']
# [47964, 14420, 27616]
# ['#8d9292', '#c8c7c1', '#6c3e35']
# [22436, 26754, 18535]
# ['#bec4c3', '#8b4d28', '#fdfdfd']
# [28104, 21097, 40799]
# ['#e8ebec', '#ab834c', '#8b2f14']
# [65135, 13265, 11600]
# ['#f5f9fa', '#c28c62', '#802e1a']
# [59872, 26202, 3926]
# ['#c0c4bf', '#d16229', '#f9fcfc']
# [16638, 17360, 56002]
# ['#e47c40', '#bbc0c0', '#f7fafb']
# [15339, 15004, 59657]
# ['#c1b49c', '#f1f7f8', '#d65311']
# [10391, 61593, 18016]
# ['#c2b8a6', '#bf6c4b', '#f6fbfd']
# [11264, 20351, 58385]
# ['#ebe2d9', '#962c2f', '#000000']
# [84641, 5359, 0]
# ['#beb8a4', '#f9fcfd', '#b16d43']
# [7701, 68313, 13986]
# ['#e7f1f4', '#aca198', '#be5837']
# [25314, 15276, 17804]
# ['#7c8981', '#e5f0f0', '#d97537']
# [13044, 26471, 18879]
# ['#f3f7f7', '#d3aa78', '#ca331a']
# [67545, 14219, 8236]
# ['#ece5d5', '#3c3145', '#bd651b']
# [14601, 15564, 24918]
# ['#e6a72b', '#e0d6c8', '#584e59']
# [27762, 16210, 24054]
# ['#e0d8cb', '#c64a37', '#346990']
# [27700, 28417, 11909]
# ['#573929', '#e6e1ce', '#a67e37']
# [28058, 17264, 21500]
# ['#4f8db6', '#493d40', '#d9cf8e']
# [16795, 26724, 21196]
# ['#ba6449', '#2e395f', '#f7e38e']
# [16920, 17579, 33527]
# ['#0e3278', '#864d36', '#d1c1a2']
# [9208, 30232, 27382]
# ['#dcdfe0', '#46586f', '#a87b30']
# [38021, 13922, 13073]
# ['#e3e1dc', '#29273c', '#000000']
# [28828, 11172, 0]
# ['#ba8a77', '#503453', '#f6f0de']
# [12170, 26671, 19854]
# ['#f3f3f0', '#2a2f3f', '#a59a67']
# [52269, 17206, 20525]
# ['#986d6c', '#ccc1bb', '#402e47']
# [15134, 21165, 30601]
# ['#85282f', '#f9f8f5', '#c38554']
# [44008, 31350, 14642]
# ['#5aafd5', '#de9c83', '#0c71a7']
# [11266, 26311, 43994]
# ['#eedecb', '#df8244', '#283f6f']
# [12463, 39574, 16290]
# ['#e6ccae', '#bd6b31', '#233f72']
# [17798, 37526, 13003]
# ['#b25828', '#ebebe9', '#9ea5a0']
# [24012, 38815, 8811]
# ['#968a89', '#395775', '#704b29']
# [32324, 3385, 34424]

# %%
print len(pixels_num_color)
# Out:
# 260

# %%
print len(hexcodes_dominant_color)
# Out:
# 260

# %%
pixels_num_color[0]
# Out:
# [40663, 16677, 32660]

# %%
hexcodes_dominant_color[0][np.argmax(pixels_num_color[0])]
# Out:
# '#fdfcfc'

# %%
most_domin_colors = []
for i in range(len(pixels_num_color)):
    most_domin_colors.append(hexcodes_dominant_color[i][np.argmax(pixels_num_color[i])])

# %%
# most_domin_colors return the most dominant color in each image
print most_domin_colors
# Out:
# ['#fdfcfc', '#da5b23', '#bd642e', '#4e186f', '#d6bf97', '#cea76e', '#ccb28f', '#b79269', '#d2b995', '#c0996d', '#ba9872', '#ceb593', '#cfb595', '#bc986f', '#b7916c', '#6d5f4d', '#d0b49b', '#b89673', '#c2a07a', '#c4a57e', '#c6a67f', '#c6a467', '#cfae82', '#c7a77a', '#c7a37a', '#fcfbfb', '#f7f8f7', '#fafaf7', '#f8f7f1', '#e2e5e5', '#f0f0ec', '#f5f5f4', '#eaebe5', '#f3f5f6', '#fcfbf9', '#dadad8', '#e1e7e8', '#f9f8f4', '#f4f3f0', '#f2f6f8', '#f6f5f3', '#f3f9fb', '#83914c', '#f4e6a4', '#eee374', '#f8f6e4', '#d5121c', '#f4f4f3', '#47366b', '#ead69c', '#f2f2f2', '#f3efe7', '#c29541', '#4d302a', '#7d311e', '#f7f6f6', '#eeeeda', '#f9f9f6', '#f6f3f2', '#e9ecec', '#f6f6f5', '#dfd2d7', '#ca2249', '#62361a', '#3f141c', '#f6f7f7', '#f5f6f4', '#561c0e', '#f6f7f6', '#f8f5f3', '#f0f0ef', '#ddae47', '#f4e3c1', '#f5f0e6', '#f4ebcd', '#f2ebcc', '#f5e0c2', '#f8f7f6', '#4c1f55', '#e9ba2f', '#dbab26', '#8f2d6f', '#fafaf9', '#f9f9f7', '#fbf9f5', '#fbf9f7', '#e1ddd1', '#d5cdd2', '#e3d6b3', '#ecc8a2', '#451e5a', '#0980b9', '#f4ece4', '#dbcbc0', '#dd592a', '#100b0e', '#ebeae7', '#faf8f4', '#f8f5f2', '#3ca45d', '#fbf9f6', '#f4f3ee', '#f1c55a', '#38518b', '#075b98', '#edc269', '#edc46d', '#da9d2d', '#fafaf7', '#f3f0ea', '#faf9f7', '#faf9f7', '#5f4f74', '#cb3c2b', '#0f5d8a', '#f4f6f6', '#fbfbfa', '#edeecd', '#a5ad30', '#eaeae6', '#d29847', '#cbcdc4', '#c29573', '#f2f3f2', '#d38e9d', '#faf8f2', '#444971', '#422f2f', '#a2792d', '#e1d9c5', '#f6f4f4', '#f0e4db', '#f9f9f8', '#5a173e', '#d9d7cf', '#f6f5f3', '#1c6089', '#bdb49d', '#fafbfc', '#f4ede7', '#16acd5', '#dad8e0', '#f9f6f2', '#f2e0d2', '#f6f3f7', '#e9eef3', '#f5edee', '#f5f5f5', '#f5e5c8', '#d5d0c9', '#7f552b', '#fcfbfa', '#f5f5f3', '#fcfaf8', '#f8f5f0', '#eeedea', '#fbfaf7', '#f4f3f3', '#f2f0eb', '#eedbca', '#e7e6dd', '#f5f7f6', '#fbf9f7', '#77131c', '#faf8f7', '#f9f9fa', '#faf9f8', '#e3e3e3', '#fdfdfb', '#faf9f6', '#f1f2f3', '#f6f4f3', '#fafaf9', '#8a8858', '#fcfbfa', '#f8f8f7', '#fcfbf9', '#e4dad8', '#f0efdf', '#732316', '#8c8b63', '#cf683b', '#fbfaf7', '#c08c34', '#313729', '#b5896c', '#f3f2eb', '#f6f4f0', '#f8f7ef', '#f7f3ee', '#fcfaf5', '#daab65', '#5a2d4f', '#e5b262', '#faf8f4', '#f9fafb', '#f8f9f5', '#faf9f0', '#dbd3c7', '#fdfcfb', '#f8f9f7', '#f1f1f2', '#f5f3f2', '#f6f5f2', '#e7e9e2', '#ece9e6', '#f3f2f5', '#f6f3ea', '#fcfcfb', '#7d5820', '#eeb83e', '#f6f6f1', '#a87b39', '#cd2d2d', '#b9621f', '#125e8d', '#5a2951', '#c08d46', '#f7f4f0', '#9b292b', '#f6f5f3', '#792521', '#edebeb', '#cd2527', '#f3973b', '#ca2628', '#793728', '#f1f7f9', '#fafaf8', '#c8c7c1', '#fdfdfd', '#e8ebec', '#f5f9fa', '#f9fcfc', '#f7fafb', '#f1f7f8', '#f6fbfd', '#ebe2d9', '#f9fcfd', '#e7f1f4', '#e5f0f0', '#f3f7f7', '#bd651b', '#e6a72b', '#c64a37', '#573929', '#493d40', '#f7e38e', '#864d36', '#dcdfe0', '#e3e1dc', '#503453', '#f3f3f0', '#402e47', '#85282f', '#0c71a7', '#df8244', '#bd6b31', '#ebebe9', '#704b29']

# %%
print most_domin_colors[48]
# Out:
# #47366b

# %%
def hex_to_rgb(value):
    value = value.lstrip('#')
    lv = len(value)
    return tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))

# %%
hex_to_rgb('#958d8d')
# Out:
# (149, 141, 141)

# %%
def closest_colour(requested_colour):
    pri_color = ['Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Violet', 'Brown', 'Black', 'Grey', 'White']
    pri_color = [x.lower() for x in pri_color]
    min_colours = {}
    #for key, name in webcolors.css3_hex_to_names.items():
    for key, name in [x for x in itertools.ifilter(lambda x: x[1]  in pri_color, webcolors.css3_hex_to_names.items())]:
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

# %%
closest_colour(hex_to_rgb(most_domin_colors[0]))
# Out:
# u'white'

# %%
domin_colors = []
for i in range(260):
    domin_colors.append(closest_colour(hex_to_rgb(most_domin_colors[i])))

# %%
print domin_colors
# Out:
# [u'white', u'brown', u'brown', u'brown', u'violet', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'grey', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'grey', u'white', u'yellow', u'white', u'red', u'white', u'grey', u'white', u'white', u'white', u'orange', u'brown', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'brown', u'black', u'white', u'white', u'brown', u'white', u'white', u'white', u'orange', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'orange', u'orange', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'violet', u'brown', u'grey', u'white', u'violet', u'brown', u'black', u'white', u'white', u'white', u'grey', u'white', u'white', u'orange', u'grey', u'grey', u'orange', u'orange', u'orange', u'white', u'white', u'white', u'white', u'grey', u'brown', u'grey', u'white', u'white', u'white', u'grey', u'white', u'orange', u'violet', u'grey', u'white', u'violet', u'white', u'grey', u'black', u'brown', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'grey', u'grey', u'white', u'white', u'grey', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'grey', u'white', u'white', u'white', u'white', u'white', u'brown', u'grey', u'brown', u'white', u'orange', u'black', u'grey', u'white', u'white', u'white', u'white', u'white', u'grey', u'brown', u'orange', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'orange', u'white', u'grey', u'brown', u'brown', u'grey', u'brown', u'grey', u'white', u'brown', u'white', u'brown', u'white', u'brown', u'orange', u'brown', u'brown', u'white', u'white', u'violet', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'white', u'brown', u'orange', u'brown', u'brown', u'brown', u'white', u'brown', u'white', u'white', u'brown', u'white', u'brown', u'brown', u'grey', u'orange', u'brown', u'white', u'brown']

# %%
def genDominColor(row):
    return domin_colors[row['index'] - 1]

# %%
df['most_domin_color'] = df.apply(genDominColor, axis = 1)

# %%
df.head()
# Out:
#   target_market  score                                        cover_image  \
# 0        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 1        Family     52  http://cerealfacts.org/media/cereal_images/Ann...
# 2        Family     50  http://cerealfacts.org/media/cereal_images/Ann...
# 3        Family     64  http://cerealfacts.org/media/cereal_images/Ann...
# 4        Family     58  http://cerealfacts.org/media/cereal_images/Bar...
#
#   sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 0          24%           3%            293                  7
# 1          24%           3%            310                  7
# 2          24%           3%            293                  7
# 3           7%           3%            379                  2
# 4          23%          10%            267                  7
#
#    fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 0                  1                  85                   120
# 1                  1                  90                   110
# 2                  1                  85                   120
# 3                  1                 110                   120
# 4                  3                  80                   120
#
#          ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 0        ...          35.58   71.37  208.29  54.28  86.32  62.01
# 1        ...          53.31  107.21  195.62  46.53  48.07  54.99
# 2        ...          65.40  123.12  191.40  52.63  60.91  40.15
# 3        ...          95.78   78.63  115.69  47.58  71.51  58.18
# 4        ...         108.41  153.04  186.66  48.37  51.09  53.44
#
#    most_fre_color  most_fre_color_count  \
# 0         #e70000                   256
# 1         #d8501e                   256
# 2         #bd582a                   256
# 3         #581680                  1272
# 4         #ffffff                   681
#
#                                            file_name  most_domin_color
# 0                    img_001_anniesfruitybunnies.jpg             white
# 1                     img_002_annieshoneybunnies.jpg             brown
# 2              img_003_anniescinnamonrollbunnyos.jpg             brown
# 3                   img_004_anniesorganicbunnyos.jpg             brown
# 4  img_005_barbarasbakerypuffinspuffscrunchycocoa...            violet
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#     target_market  score                                        cover_image  \
# 255         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 256         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 257         Adult     70  http://cerealfacts.org/media/cereal_images/Qua...
# 258        Family     58  http://cerealfacts.org/media/cereal_images/Qua...
# 259        Family     58  http://cerealfacts.org/media/cereal_images/Qua...
#
#     sugar_result fiber_result  sodium_result  sugar_per_serving  \
# 255          16%           9%            339                  9
# 256          16%           9%            339                  9
# 257          16%           9%            339                  9
# 258          19%          19%            281                  6
# 259          22%          19%            281                  7
#
#      fiber_per_serving  sodium_per_serving  calories_per_serving  \
# 255                  5                 190                   210
# 256                  5                 190                   210
# 257                  5                 190                   210
# 258                  6                  90                   110
# 259                  6                  90                   110
#
#            ...         b_mean  g_mean  r_mean   b_sd   g_sd   r_sd  \
# 255        ...         164.55  136.89   90.92  62.61  58.52  98.70
# 256        ...          97.41  126.17  178.93  58.60  61.11  85.87
# 257        ...          91.22  121.25  167.26  65.59  61.71  74.12
# 258        ...         158.91  175.17  203.98  90.90  73.27  47.04
# 259        ...          88.67  104.01  126.50  51.30  39.40  38.09
#
#      most_fre_color  most_fre_color_count  \
# 255         #0093d8                   249
# 256         #26397b                  1792
# 257         #1b4482                   256
# 258         #e4e3e1                   148
# 259         #817d7c                   256
#
#                                          file_name  most_domin_color
# 255     img_256_quakeroatmealsquaresbrownsugar.jpg              grey
# 256       img_257_quakeroatmealsquarescinnamon.jpg            orange
# 257    img_258_quakeroatmealsquaresgoldenmaple.jpg             brown
# 258     img_259_quakerlifecrunchtimestrawberry.jpg             white
# 259  img_260_quakerlifecrunchtimeapplecinnamon.jpg             brown
#
# [5 rows x 28 columns]

# %%
df.to_csv('../data/data_updated.csv')
